# %% [markdown]
# # Stuart's Models

# %%
## standard and modeling imports

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from Modules import *
sns.set()
# %matplotlib inline
import imblearn

from sklearn.model_selection import train_test_split, KFold, cross_val_score, RandomizedSearchCV,GridSearchCV
from sklearn.pipeline import FeatureUnion
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, f1_score, precision_score, recall_score
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.pipeline import Pipeline 
from sklearn.ensemble import RandomForestClassifier
from time import time
from sklearn.externals import joblib
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import RFE, SelectKBest
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score, KFold
#import xgboost as xgb
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from imblearn.over_sampling import SMOTE

# %%
#read in the data

data = pd.read_csv('Data/sequential_data.csv')
df = data.iloc[:, 1:]
y = df['Y']

df.head().T
# Out:
#                                              0              1             2  \
# LIMIT_BAL                         20000.000000  120000.000000  90000.000000
# AGE                                  24.000000      26.000000     34.000000
# PAY_1                                 2.000000      -1.000000      0.000000
# PAY_2                                 2.000000       2.000000      0.000000
# PAY_3                                -1.000000       0.000000      0.000000
# PAY_4                                -1.000000       0.000000      0.000000
# PAY_5                                -2.000000       0.000000      0.000000
# PAY_6                                -2.000000       2.000000      0.000000
# BILL_AMT1                          3913.000000    2682.000000  29239.000000
# BILL_AMT2                          3102.000000    1725.000000  14027.000000
# BILL_AMT3                           689.000000    2682.000000  13559.000000
# BILL_AMT4                             0.000000    3272.000000  14331.000000
# BILL_AMT5                             0.000000    3455.000000  14948.000000
# BILL_AMT6                             0.000000    3261.000000  15549.000000
# PAY_AMT1                              0.000000       0.000000   1518.000000
# PAY_AMT2                            689.000000    1000.000000   1500.000000
# PAY_AMT3                              0.000000    1000.000000   1000.000000
# PAY_AMT4                              0.000000    1000.000000   1000.000000
# PAY_AMT5                              0.000000       0.000000   1000.000000
# PAY_AMT6                              0.000000    2000.000000   5000.000000
# Y                                     1.000000       1.000000      0.000000
# SEX_Female                            1.000000       1.000000      1.000000
# SEX_Male                              0.000000       0.000000      0.000000
# EDUCATION_Graduate School             0.000000       0.000000      0.000000
# EDUCATION_Other                       0.000000       0.000000      0.000000
# EDUCATION_University                  1.000000       1.000000      1.000000
# MARRIAGE_Married                      1.000000       0.000000      0.000000
# MARRIAGE_Non-married                  0.000000       1.000000      1.000000
# OUTSTANDING_BAL1                   3913.000000    2682.000000  27721.000000
# OUTSTANDING_BAL2                   2413.000000     725.000000  12527.000000
# ...                                        ...            ...           ...
# OUTSTANDING_BAL4                      0.000000    2272.000000  13331.000000
# OUTSTANDING_BAL5                      0.000000    3455.000000  13948.000000
# OUTSTANDING_BAL6                      0.000000    1261.000000  10549.000000
# OUSTANDING_BAL_1_INDICATOR            1.000000       1.000000      1.000000
# OUSTANDING_BAL_2_INDICATOR            1.000000       0.000000      0.000000
# OUSTANDING_BAL_3_INDICATOR            1.000000       0.000000      0.000000
# OUSTANDING_BAL_4_INDICATOR            0.000000       0.000000      0.000000
# OUSTANDING_BAL_5_INDICATOR            0.000000       1.000000      1.000000
# PERCENT_OF_LIMIT_BAL1                 0.195650       0.022350      0.308011
# PERCENT_OF_LIMIT_BAL2                 0.120650       0.006042      0.139189
# PERCENT_OF_LIMIT_BAL3                 0.034450       0.014017      0.139544
# PERCENT_OF_LIMIT_BAL4                 0.000000       0.018933      0.148122
# PERCENT_OF_LIMIT_BAL5                 0.000000       0.028792      0.154978
# PERCENT_OF_LIMIT_BAL6                 0.000000       0.010508      0.117211
# PERCENT_OF_LIMIT_BAL_1_INDICATOR      1.000000       1.000000      1.000000
# PERCENT_OF_LIMIT_BAL_2_INDICATOR      1.000000       0.000000      0.000000
# PERCENT_OF_LIMIT_BAL_3_INDICATOR      1.000000       0.000000      0.000000
# PERCENT_OF_LIMIT_BAL_4_INDICATOR      0.000000       0.000000      0.000000
# PERCENT_OF_LIMIT_BAL_5_INDICATOR      0.000000       1.000000      1.000000
# PAY_RATIO_1                           0.000000       0.000000      0.051917
# PAY_RATIO_2                           0.222115       0.579710      0.106937
# PAY_RATIO_3                           0.000000       0.372856      0.073752
# PAY_RATIO_4                           1.000000       0.305623      0.069779
# PAY_RATIO_5                           1.000000       0.000000      0.066899
# PAY_RATIO_6                           1.000000       0.613309      0.321564
# PAY_RATIO_1_INDICATOR                 1.000000       1.000000      1.000000
# PAY_RATIO_2_INDICATOR                 0.000000       0.000000      0.000000
# PAY_RATIO_3_INDICATOR                 0.600000       0.000000      0.000000
# PAY_RATIO_4_INDICATOR                 0.000000       0.000000      0.000000
# PAY_RATIO_5_INDICATOR                 0.000000       0.200000      0.200000
#
#                                              3             4
# LIMIT_BAL                         50000.000000  50000.000000
# AGE                                  37.000000     57.000000
# PAY_1                                 0.000000     -1.000000
# PAY_2                                 0.000000      0.000000
# PAY_3                                 0.000000     -1.000000
# PAY_4                                 0.000000      0.000000
# PAY_5                                 0.000000      0.000000
# PAY_6                                 0.000000      0.000000
# BILL_AMT1                         46990.000000   8617.000000
# BILL_AMT2                         48233.000000   5670.000000
# BILL_AMT3                         49291.000000  35835.000000
# BILL_AMT4                         28314.000000  20940.000000
# BILL_AMT5                         28959.000000  19146.000000
# BILL_AMT6                         29547.000000  19131.000000
# PAY_AMT1                           2000.000000   2000.000000
# PAY_AMT2                           2019.000000  36681.000000
# PAY_AMT3                           1200.000000  10000.000000
# PAY_AMT4                           1100.000000   9000.000000
# PAY_AMT5                           1069.000000    689.000000
# PAY_AMT6                           1000.000000    679.000000
# Y                                     0.000000      0.000000
# SEX_Female                            1.000000      0.000000
# SEX_Male                              0.000000      1.000000
# EDUCATION_Graduate School             0.000000      0.000000
# EDUCATION_Other                       0.000000      0.000000
# EDUCATION_University                  1.000000      1.000000
# MARRIAGE_Married                      1.000000      1.000000
# MARRIAGE_Non-married                  0.000000      0.000000
# OUTSTANDING_BAL1                  44990.000000   6617.000000
# OUTSTANDING_BAL2                  46214.000000 -31011.000000
# ...                                        ...           ...
# OUTSTANDING_BAL4                  27214.000000  11940.000000
# OUTSTANDING_BAL5                  27890.000000  18457.000000
# OUTSTANDING_BAL6                  28547.000000  18452.000000
# OUSTANDING_BAL_1_INDICATOR            0.000000      1.000000
# OUSTANDING_BAL_2_INDICATOR            0.000000      0.000000
# OUSTANDING_BAL_3_INDICATOR            1.000000      1.000000
# OUSTANDING_BAL_4_INDICATOR            0.000000      0.000000
# OUSTANDING_BAL_5_INDICATOR            0.000000      1.000000
# PERCENT_OF_LIMIT_BAL1                 0.899800      0.132340
# PERCENT_OF_LIMIT_BAL2                 0.924280     -0.620220
# PERCENT_OF_LIMIT_BAL3                 0.961820      0.516700
# PERCENT_OF_LIMIT_BAL4                 0.544280      0.238800
# PERCENT_OF_LIMIT_BAL5                 0.557800      0.369140
# PERCENT_OF_LIMIT_BAL6                 0.570940      0.369040
# PERCENT_OF_LIMIT_BAL_1_INDICATOR      0.000000      1.000000
# PERCENT_OF_LIMIT_BAL_2_INDICATOR      0.000000      0.000000
# PERCENT_OF_LIMIT_BAL_3_INDICATOR      1.000000      1.000000
# PERCENT_OF_LIMIT_BAL_4_INDICATOR      0.000000      0.000000
# PERCENT_OF_LIMIT_BAL_5_INDICATOR      0.000000      1.000000
# PAY_RATIO_1                           0.042562      0.232099
# PAY_RATIO_2                           0.041859      6.469312
# PAY_RATIO_3                           0.024345      0.279057
# PAY_RATIO_4                           0.038850      0.429799
# PAY_RATIO_5                           0.036914      0.035987
# PAY_RATIO_6                           0.033844      0.035492
# PAY_RATIO_1_INDICATOR                 0.000000      1.000000
# PAY_RATIO_2_INDICATOR                 0.000000      0.000000
# PAY_RATIO_3_INDICATOR                 0.600000      0.600000
# PAY_RATIO_4_INDICATOR                 0.000000      0.000000
# PAY_RATIO_5_INDICATOR                 0.000000      0.000000
#
# [61 rows x 5 columns]

# %%
X = df.drop(columns = 'Y')
y = df['Y']

# %%
df.describe()
# Out:
#             LIMIT_BAL           AGE         PAY_1         PAY_2         PAY_3  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     35.485500     -0.016700     -0.133767     -0.166200
# std     129747.661567      9.217904      1.123802      1.197186      1.196868
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%      50000.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     34.000000      0.000000      0.000000      0.000000
# 75%     240000.000000     41.000000      0.000000      0.000000      0.000000
# max    1000000.000000     79.000000      8.000000      8.000000      8.000000
#
#               PAY_4         PAY_5         PAY_6      BILL_AMT1      BILL_AMT2  \
# count  30000.000000  30000.000000  30000.000000   30000.000000   30000.000000
# mean      -0.220667     -0.266200     -0.291100   51223.330900   49179.075167
# std        1.169139      1.133187      1.149988   73635.860576   71173.768783
# min       -2.000000     -2.000000     -2.000000 -165580.000000  -69777.000000
# 25%       -1.000000     -1.000000     -1.000000    3558.750000    2984.750000
# 50%        0.000000      0.000000      0.000000   22381.500000   21200.000000
# 75%        0.000000      0.000000      0.000000   67091.000000   64006.250000
# max        8.000000      8.000000      8.000000  964511.000000  983931.000000
#
#                ...             PAY_RATIO_2   PAY_RATIO_3   PAY_RATIO_4  \
# count          ...            30000.000000  30000.000000  30000.000000
# mean           ...               -1.613257     -6.110435     -1.315520
# std            ...              104.468782    602.027008    145.552296
# min            ...           -10259.500000 -82150.000000 -17266.666667
# 25%            ...                0.037071      0.031485      0.030558
# 50%            ...                0.068384      0.055164      0.048433
# 75%            ...                0.585974      0.610268      0.606036
# max            ...             4444.333333   6333.333333   8891.357143
#
#         PAY_RATIO_5   PAY_RATIO_6  PAY_RATIO_1_INDICATOR  \
# count  30000.000000  30000.000000           30000.000000
# mean      -0.623941     -0.466207               0.434367
# std       65.830303     80.584015               0.495682
# min    -7483.947368 -11349.571429               0.000000
# 25%        0.035135      0.034944               0.000000
# 50%        0.053873      0.056917               0.000000
# 75%        0.825986      1.000000               1.000000
# max     1738.424242   2643.330000               1.000000
#
#        PAY_RATIO_2_INDICATOR  PAY_RATIO_3_INDICATOR  PAY_RATIO_4_INDICATOR  \
# count           30000.000000           30000.000000           30000.000000
# mean                0.289280               0.250180               0.190440
# std                 0.384377               0.295839               0.199775
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.800000               0.600000               0.400000
# max                 0.800000               0.600000               0.400000
#
#        PAY_RATIO_5_INDICATOR
# count           30000.000000
# mean                0.085040
# std                 0.098876
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.200000
# max                 0.200000
#
# [8 rows x 61 columns]

# %%
##splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 2019, test_size = .2)

# %%
#create  oversampled data to train on
oversampler = SMOTE(random_state = 2019)
X_train_oversampled, y_train_oversampled = oversampler.fit_resample(X_train, y_train)

# %%
#Put the oversampled data back into a dataframe
X_train_oversampled = pd.DataFrame(X_train_oversampled, columns = X_train.columns)
y_train_oversampled = pd.Series(y_train_oversampled)

# %%
#check the size of the data
print("X_train_oversampled", X_train_oversampled.shape)
print("X_test",X_test.shape)
print("y_train_oversampled",y_train_oversampled.shape)
print("y_test",y_test.shape)
# Out:
# X_train_oversampled (37308, 60)
# X_test (6000, 60)
# y_train_oversampled (37308,)
# y_test (6000,)

# %% [markdown]
# # Logistic Regression
# ## Unable to get f1 score on 5-fold cross validation

# %%
clfLR = LogisticRegression(solver = 'lbfgs',
                           max_iter = 1000,                  #increased from 500 to 1000 
                          random_state = 2019)
clfLR.fit(X_train_oversampled,y_train_oversampled)

predLR = clfLR.predict(X_test)

# %%
# Cross Validation
cross_val_score_LR = cross_val_score(clfLR, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LR.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predLR).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predLR).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predLR).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predLR).round(2))
# Out:
# cross_val_score:  0.78
# precision score is  0.28
# recall_score is  0.7124
# f1 score is  0.406
# ROC AUC is  0.61

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(clfLR, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.0016949152542372885

# %% [markdown]
# # Support Vector Classification (SVC)
# ## Unable to run on Jupyter Classroom

# %%
clfSVC = SVC(kernel = 'rbf',
             gamma = 'scale',
                random_state = 2019)

clfSVC.fit(X_train_oversampled,y_train_oversampled)

predSVC = clfSVC.predict(X_test)

# %%
# Cross Validation
cross_val_score_SVC = cross_val_score(clfSVC, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_SVC.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predSVC).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predSVC).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predSVC).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predSVC).round(2))

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(p, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation results: {np.mean(results)}")

# %% [markdown]
# # Kneighbours

# %%
clfKNN = KNeighborsClassifier(n_neighbors = 3)
k = clfKNN.fit(X_train_oversampled,y_train_oversampled)

predKNN = clfKNN.predict(X_test)

# %%
# Cross Validation
cross_val_score_KNN = cross_val_score(clfKNN, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_KNN.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predKNN).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predKNN).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predKNN).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predKNN).round(2))
# Out:
# cross_val_score:  0.74
# precision score is  0.27
# recall_score is  0.4698
# f1 score is  0.341
# ROC AUC is  0.56

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(k, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.2630349123135688

# %% [markdown]
# # Random Forest Classifier

# %%
clfRF = RandomForestClassifier(criterion = 'gini',
                              n_estimators = 100,
                              verbose = False,
                              random_state = 2019)             #switched random state from 0 to 2019

r = clfRF.fit(X_train_oversampled,y_train_oversampled)

predRF = clfRF.predict(X_test)

# %%
# Cross Validation
cross_val_score_RF = cross_val_score(clfRF, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_RF.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predRF).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predRF).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predRF).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predRF).round(2))
# Out:
# cross_val_score:  0.82
# precision score is  0.62
# recall_score is  0.4116
# f1 score is  0.496
# ROC AUC is  0.67

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(r, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.46299637307347385

# %% [markdown]
# # light gbm

# %%
clfLGB = LGBMClassifier(n_estimators = 100,
                           learning_rate = .2,
                           random_state = 2019)      #switched random state from 0 to 2019

g = clfLGB.fit(X_train_oversampled,y_train_oversampled)

predLGB = g.predict(X_test)

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfLGB, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predLGB).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predLGB).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predLGB).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predLGB).round(2))
# Out:
# cross_val_score:  0.82
# precision score is  0.67
# recall_score is  0.3814
# f1 score is  0.485
# ROC AUC is  0.66

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(g, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.46925732620499083

# %% [markdown]
# # Cat Boost Classifier

# %% [markdown]
# https://catboost.ai/docs/concepts/python-reference_catboostclassifier.html

# %%
clfCB = CatBoostClassifier(iterations = 100,
                           learning_rate = .2,
                           depth = 5,
                           eval_metric = 'AUC',
                           random_seed = 0)

clfCB.fit(X_train_oversampled,y_train_oversampled)

predCB = clfCB.predict(X_test)
# Out:
# 0:	total: 120ms	remaining: 11.8s
# 1:	total: 176ms	remaining: 8.63s
# 2:	total: 234ms	remaining: 7.56s
# 3:	total: 291ms	remaining: 6.98s
# 4:	total: 346ms	remaining: 6.58s
# 5:	total: 402ms	remaining: 6.3s
# 6:	total: 456ms	remaining: 6.06s
# 7:	total: 516ms	remaining: 5.93s
# 8:	total: 572ms	remaining: 5.78s
# 9:	total: 628ms	remaining: 5.65s
# 10:	total: 683ms	remaining: 5.53s
# 11:	total: 738ms	remaining: 5.41s
# 12:	total: 790ms	remaining: 5.29s
# 13:	total: 848ms	remaining: 5.21s
# 14:	total: 903ms	remaining: 5.12s
# 15:	total: 957ms	remaining: 5.02s
# 16:	total: 1.02s	remaining: 4.97s
# 17:	total: 1.08s	remaining: 4.92s
# 18:	total: 1.15s	remaining: 4.89s
# 19:	total: 1.21s	remaining: 4.84s
# 20:	total: 1.27s	remaining: 4.79s
# 21:	total: 1.33s	remaining: 4.73s
# 22:	total: 1.39s	remaining: 4.66s
# 23:	total: 1.45s	remaining: 4.6s
# 24:	total: 1.51s	remaining: 4.54s
# 25:	total: 1.57s	remaining: 4.47s
# 26:	total: 1.63s	remaining: 4.42s
# 27:	total: 1.7s	remaining: 4.36s
# 28:	total: 1.76s	remaining: 4.31s
# 29:	total: 1.82s	remaining: 4.25s
# 30:	total: 1.89s	remaining: 4.2s
# 31:	total: 1.95s	remaining: 4.14s
# 32:	total: 2.01s	remaining: 4.08s
# 33:	total: 2.07s	remaining: 4.02s
# 34:	total: 2.13s	remaining: 3.96s
# 35:	total: 2.2s	remaining: 3.91s
# 36:	total: 2.26s	remaining: 3.85s
# 37:	total: 2.32s	remaining: 3.79s
# 38:	total: 2.38s	remaining: 3.73s
# 39:	total: 2.44s	remaining: 3.67s
# 40:	total: 2.5s	remaining: 3.6s
# 41:	total: 2.56s	remaining: 3.54s
# 42:	total: 2.62s	remaining: 3.48s
# 43:	total: 2.68s	remaining: 3.41s
# 44:	total: 2.74s	remaining: 3.35s
# 45:	total: 2.8s	remaining: 3.29s
# 46:	total: 2.86s	remaining: 3.22s
# 47:	total: 2.92s	remaining: 3.16s
# 48:	total: 2.98s	remaining: 3.1s
# 49:	total: 3.04s	remaining: 3.04s
# 50:	total: 3.1s	remaining: 2.98s
# 51:	total: 3.17s	remaining: 2.92s
# 52:	total: 3.23s	remaining: 2.86s
# 53:	total: 3.29s	remaining: 2.8s
# 54:	total: 3.35s	remaining: 2.74s
# 55:	total: 3.42s	remaining: 2.69s
# 56:	total: 3.48s	remaining: 2.63s
# 57:	total: 3.55s	remaining: 2.57s
# 58:	total: 3.61s	remaining: 2.51s
# 59:	total: 3.67s	remaining: 2.45s
# 60:	total: 3.73s	remaining: 2.38s
# 61:	total: 3.79s	remaining: 2.32s
# 62:	total: 3.85s	remaining: 2.26s
# 63:	total: 3.92s	remaining: 2.2s
# 64:	total: 3.97s	remaining: 2.14s
# 65:	total: 4.04s	remaining: 2.08s
# 66:	total: 4.09s	remaining: 2.02s
# 67:	total: 4.15s	remaining: 1.95s
# 68:	total: 4.21s	remaining: 1.89s
# 69:	total: 4.28s	remaining: 1.83s
# 70:	total: 4.34s	remaining: 1.77s
# 71:	total: 4.4s	remaining: 1.71s
# 72:	total: 4.46s	remaining: 1.65s
# 73:	total: 4.52s	remaining: 1.59s
# 74:	total: 4.58s	remaining: 1.53s
# 75:	total: 4.64s	remaining: 1.47s
# 76:	total: 4.7s	remaining: 1.41s
# 77:	total: 4.77s	remaining: 1.34s
# 78:	total: 4.83s	remaining: 1.28s
# 79:	total: 4.89s	remaining: 1.22s
# 80:	total: 4.95s	remaining: 1.16s
# 81:	total: 5.01s	remaining: 1.1s
# 82:	total: 5.08s	remaining: 1.04s
# 83:	total: 5.11s	remaining: 973ms
# 84:	total: 5.17s	remaining: 912ms
# 85:	total: 5.23s	remaining: 851ms
# 86:	total: 5.29s	remaining: 790ms
# 87:	total: 5.35s	remaining: 729ms
# 88:	total: 5.41s	remaining: 669ms
# 89:	total: 5.47s	remaining: 607ms
# 90:	total: 5.52s	remaining: 546ms
# 91:	total: 5.59s	remaining: 486ms
# 92:	total: 5.65s	remaining: 425ms
# 93:	total: 5.71s	remaining: 364ms
# 94:	total: 5.77s	remaining: 304ms
# 95:	total: 5.83s	remaining: 243ms
# 96:	total: 5.89s	remaining: 182ms
# 97:	total: 5.95s	remaining: 121ms
# 98:	total: 5.99s	remaining: 60.5ms
# 99:	total: 6.05s	remaining: 0us

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfCB, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predCB).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predCB).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predCB).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predCB).round(2))
# Out:
# 0:	total: 34.2ms	remaining: 3.38s
# 1:	total: 64.1ms	remaining: 3.14s
# 2:	total: 93.9ms	remaining: 3.04s
# 3:	total: 121ms	remaining: 2.89s
# 4:	total: 150ms	remaining: 2.84s
# 5:	total: 183ms	remaining: 2.86s
# 6:	total: 214ms	remaining: 2.84s
# 7:	total: 245ms	remaining: 2.81s
# 8:	total: 273ms	remaining: 2.76s
# 9:	total: 302ms	remaining: 2.72s
# 10:	total: 330ms	remaining: 2.67s
# 11:	total: 359ms	remaining: 2.64s
# 12:	total: 389ms	remaining: 2.6s
# 13:	total: 417ms	remaining: 2.56s
# 14:	total: 448ms	remaining: 2.54s
# 15:	total: 479ms	remaining: 2.52s
# 16:	total: 508ms	remaining: 2.48s
# 17:	total: 536ms	remaining: 2.44s
# 18:	total: 566ms	remaining: 2.41s
# 19:	total: 593ms	remaining: 2.37s
# 20:	total: 619ms	remaining: 2.33s
# 21:	total: 654ms	remaining: 2.32s
# 22:	total: 683ms	remaining: 2.29s
# 23:	total: 713ms	remaining: 2.26s
# 24:	total: 744ms	remaining: 2.23s
# 25:	total: 775ms	remaining: 2.2s
# 26:	total: 806ms	remaining: 2.18s
# 27:	total: 838ms	remaining: 2.15s
# 28:	total: 867ms	remaining: 2.12s
# 29:	total: 893ms	remaining: 2.08s
# 30:	total: 928ms	remaining: 2.07s
# 31:	total: 957ms	remaining: 2.03s
# 32:	total: 986ms	remaining: 2s
# 33:	total: 1.02s	remaining: 1.97s
# 34:	total: 1.04s	remaining: 1.94s
# 35:	total: 1.08s	remaining: 1.91s
# 36:	total: 1.11s	remaining: 1.89s
# 37:	total: 1.14s	remaining: 1.86s
# 38:	total: 1.17s	remaining: 1.82s
# 39:	total: 1.2s	remaining: 1.79s
# 40:	total: 1.22s	remaining: 1.76s
# 41:	total: 1.25s	remaining: 1.73s
# 42:	total: 1.28s	remaining: 1.7s
# 43:	total: 1.31s	remaining: 1.67s
# 44:	total: 1.34s	remaining: 1.64s
# 45:	total: 1.37s	remaining: 1.61s
# 46:	total: 1.4s	remaining: 1.58s
# 47:	total: 1.43s	remaining: 1.55s
# 48:	total: 1.46s	remaining: 1.52s
# 49:	total: 1.49s	remaining: 1.49s
# 50:	total: 1.52s	remaining: 1.46s
# 51:	total: 1.54s	remaining: 1.43s
# 52:	total: 1.57s	remaining: 1.4s
# 53:	total: 1.6s	remaining: 1.37s
# 54:	total: 1.64s	remaining: 1.34s
# 55:	total: 1.66s	remaining: 1.31s
# 56:	total: 1.7s	remaining: 1.28s
# 57:	total: 1.72s	remaining: 1.24s
# 58:	total: 1.74s	remaining: 1.21s
# 59:	total: 1.77s	remaining: 1.18s
# 60:	total: 1.8s	remaining: 1.15s
# 61:	total: 1.83s	remaining: 1.12s
# 62:	total: 1.86s	remaining: 1.09s
# 63:	total: 1.89s	remaining: 1.06s
# 64:	total: 1.91s	remaining: 1.03s
# 65:	total: 1.95s	remaining: 1s
# 66:	total: 1.97s	remaining: 970ms
# 67:	total: 2s	remaining: 943ms
# 68:	total: 2.03s	remaining: 912ms
# 69:	total: 2.06s	remaining: 882ms
# 70:	total: 2.09s	remaining: 852ms
# 71:	total: 2.11s	remaining: 822ms
# 72:	total: 2.14s	remaining: 793ms
# 73:	total: 2.17s	remaining: 764ms
# 74:	total: 2.21s	remaining: 735ms
# 75:	total: 2.24s	remaining: 706ms
# 76:	total: 2.26s	remaining: 676ms
# 77:	total: 2.29s	remaining: 647ms
# 78:	total: 2.32s	remaining: 617ms
# 79:	total: 2.35s	remaining: 588ms
# 80:	total: 2.38s	remaining: 559ms
# 81:	total: 2.41s	remaining: 529ms
# 82:	total: 2.44s	remaining: 500ms
# 83:	total: 2.47s	remaining: 470ms
# 84:	total: 2.5s	remaining: 440ms
# 85:	total: 2.52s	remaining: 411ms
# 86:	total: 2.55s	remaining: 381ms
# 87:	total: 2.58s	remaining: 352ms
# 88:	total: 2.61s	remaining: 322ms
# 89:	total: 2.63s	remaining: 293ms
# 90:	total: 2.66s	remaining: 263ms
# 91:	total: 2.69s	remaining: 234ms
# 92:	total: 2.72s	remaining: 205ms
# 93:	total: 2.75s	remaining: 175ms
# 94:	total: 2.78s	remaining: 146ms
# 95:	total: 2.81s	remaining: 117ms
# 96:	total: 2.84s	remaining: 87.7ms
# 97:	total: 2.87s	remaining: 58.5ms
# 98:	total: 2.9s	remaining: 29.2ms
# 99:	total: 2.92s	remaining: 0us
# 0:	total: 28.4ms	remaining: 2.81s
# 1:	total: 57.3ms	remaining: 2.81s
# 2:	total: 87.6ms	remaining: 2.83s
# 3:	total: 122ms	remaining: 2.93s
# 4:	total: 150ms	remaining: 2.86s
# 5:	total: 180ms	remaining: 2.81s
# 6:	total: 209ms	remaining: 2.78s
# 7:	total: 240ms	remaining: 2.76s
# 8:	total: 271ms	remaining: 2.74s
# 9:	total: 302ms	remaining: 2.71s
# 10:	total: 332ms	remaining: 2.69s
# 11:	total: 361ms	remaining: 2.65s
# 12:	total: 390ms	remaining: 2.61s
# 13:	total: 418ms	remaining: 2.56s
# 14:	total: 447ms	remaining: 2.53s
# 15:	total: 478ms	remaining: 2.51s
# 16:	total: 509ms	remaining: 2.49s
# 17:	total: 542ms	remaining: 2.47s
# 18:	total: 569ms	remaining: 2.42s
# 19:	total: 600ms	remaining: 2.4s
# 20:	total: 631ms	remaining: 2.38s
# 21:	total: 663ms	remaining: 2.35s
# 22:	total: 694ms	remaining: 2.32s
# 23:	total: 723ms	remaining: 2.29s
# 24:	total: 754ms	remaining: 2.26s
# 25:	total: 785ms	remaining: 2.23s
# 26:	total: 816ms	remaining: 2.21s
# 27:	total: 849ms	remaining: 2.18s
# 28:	total: 880ms	remaining: 2.15s
# 29:	total: 909ms	remaining: 2.12s
# 30:	total: 939ms	remaining: 2.09s
# 31:	total: 966ms	remaining: 2.05s
# 32:	total: 996ms	remaining: 2.02s
# 33:	total: 1.03s	remaining: 1.99s
# 34:	total: 1.06s	remaining: 1.96s
# 35:	total: 1.08s	remaining: 1.93s
# 36:	total: 1.11s	remaining: 1.9s
# 37:	total: 1.14s	remaining: 1.87s
# 38:	total: 1.17s	remaining: 1.83s
# 39:	total: 1.2s	remaining: 1.8s
# 40:	total: 1.23s	remaining: 1.77s
# 41:	total: 1.26s	remaining: 1.75s
# 42:	total: 1.29s	remaining: 1.71s
# 43:	total: 1.32s	remaining: 1.68s
# 44:	total: 1.35s	remaining: 1.65s
# 45:	total: 1.38s	remaining: 1.62s
# 46:	total: 1.41s	remaining: 1.59s
# 47:	total: 1.44s	remaining: 1.56s
# 48:	total: 1.48s	remaining: 1.54s
# 49:	total: 1.51s	remaining: 1.51s
# 50:	total: 1.54s	remaining: 1.48s
# 51:	total: 1.57s	remaining: 1.45s
# 52:	total: 1.6s	remaining: 1.42s
# 53:	total: 1.63s	remaining: 1.39s
# 54:	total: 1.65s	remaining: 1.35s
# 55:	total: 1.68s	remaining: 1.32s
# 56:	total: 1.72s	remaining: 1.29s
# 57:	total: 1.75s	remaining: 1.26s
# 58:	total: 1.78s	remaining: 1.24s
# 59:	total: 1.81s	remaining: 1.21s
# 60:	total: 1.84s	remaining: 1.18s
# 61:	total: 1.86s	remaining: 1.14s
# 62:	total: 1.89s	remaining: 1.11s
# 63:	total: 1.92s	remaining: 1.08s
# 64:	total: 1.94s	remaining: 1.04s
# 65:	total: 1.97s	remaining: 1.01s
# 66:	total: 2s	remaining: 986ms
# 67:	total: 2.03s	remaining: 956ms
# 68:	total: 2.05s	remaining: 923ms
# 69:	total: 2.08s	remaining: 893ms
# 70:	total: 2.11s	remaining: 863ms
# 71:	total: 2.14s	remaining: 834ms
# 72:	total: 2.17s	remaining: 804ms
# 73:	total: 2.2s	remaining: 774ms
# 74:	total: 2.23s	remaining: 744ms
# 75:	total: 2.27s	remaining: 717ms
# 76:	total: 2.3s	remaining: 687ms
# 77:	total: 2.33s	remaining: 657ms
# 78:	total: 2.36s	remaining: 627ms
# 79:	total: 2.39s	remaining: 597ms
# 80:	total: 2.42s	remaining: 567ms
# 81:	total: 2.45s	remaining: 537ms
# 82:	total: 2.48s	remaining: 507ms
# 83:	total: 2.51s	remaining: 478ms
# 84:	total: 2.54s	remaining: 447ms
# 85:	total: 2.57s	remaining: 418ms
# 86:	total: 2.6s	remaining: 388ms
# 87:	total: 2.63s	remaining: 359ms
# 88:	total: 2.66s	remaining: 329ms
# 89:	total: 2.69s	remaining: 299ms
# 90:	total: 2.73s	remaining: 270ms
# 91:	total: 2.75s	remaining: 240ms
# 92:	total: 2.79s	remaining: 210ms
# 93:	total: 2.81s	remaining: 180ms
# 94:	total: 2.83s	remaining: 149ms
# 95:	total: 2.86s	remaining: 119ms
# 96:	total: 2.89s	remaining: 89.3ms
# 97:	total: 2.91s	remaining: 59.4ms
# 98:	total: 2.94s	remaining: 29.7ms
# 99:	total: 2.97s	remaining: 0us
# 0:	total: 30.2ms	remaining: 2.99s
# 1:	total: 63ms	remaining: 3.09s
# 2:	total: 92.9ms	remaining: 3s
# 3:	total: 124ms	remaining: 2.98s
# 4:	total: 151ms	remaining: 2.88s
# 5:	total: 178ms	remaining: 2.79s
# 6:	total: 209ms	remaining: 2.78s
# 7:	total: 239ms	remaining: 2.75s
# 8:	total: 272ms	remaining: 2.75s
# 9:	total: 301ms	remaining: 2.71s
# 10:	total: 334ms	remaining: 2.7s
# 11:	total: 363ms	remaining: 2.67s
# 12:	total: 395ms	remaining: 2.64s
# 13:	total: 425ms	remaining: 2.61s
# 14:	total: 455ms	remaining: 2.58s
# 15:	total: 486ms	remaining: 2.55s
# 16:	total: 516ms	remaining: 2.52s
# 17:	total: 544ms	remaining: 2.48s
# 18:	total: 576ms	remaining: 2.45s
# 19:	total: 605ms	remaining: 2.42s
# 20:	total: 635ms	remaining: 2.39s
# 21:	total: 669ms	remaining: 2.37s
# 22:	total: 698ms	remaining: 2.34s
# 23:	total: 729ms	remaining: 2.31s
# 24:	total: 759ms	remaining: 2.28s
# 25:	total: 790ms	remaining: 2.25s
# 26:	total: 819ms	remaining: 2.21s
# 27:	total: 849ms	remaining: 2.18s
# 28:	total: 879ms	remaining: 2.15s
# 29:	total: 910ms	remaining: 2.12s
# 30:	total: 937ms	remaining: 2.09s
# 31:	total: 965ms	remaining: 2.05s
# 32:	total: 995ms	remaining: 2.02s
# 33:	total: 1.02s	remaining: 1.99s
# 34:	total: 1.05s	remaining: 1.96s
# 35:	total: 1.08s	remaining: 1.93s
# 36:	total: 1.11s	remaining: 1.9s
# 37:	total: 1.14s	remaining: 1.86s
# 38:	total: 1.17s	remaining: 1.83s
# 39:	total: 1.2s	remaining: 1.8s
# 40:	total: 1.23s	remaining: 1.77s
# 41:	total: 1.26s	remaining: 1.74s
# 42:	total: 1.29s	remaining: 1.71s
# 43:	total: 1.32s	remaining: 1.68s
# 44:	total: 1.35s	remaining: 1.65s
# 45:	total: 1.38s	remaining: 1.62s
# 46:	total: 1.41s	remaining: 1.59s
# 47:	total: 1.44s	remaining: 1.56s
# 48:	total: 1.47s	remaining: 1.53s
# 49:	total: 1.5s	remaining: 1.5s
# 50:	total: 1.53s	remaining: 1.47s
# 51:	total: 1.56s	remaining: 1.44s
# 52:	total: 1.59s	remaining: 1.41s
# 53:	total: 1.62s	remaining: 1.38s
# 54:	total: 1.65s	remaining: 1.35s
# 55:	total: 1.68s	remaining: 1.32s
# 56:	total: 1.71s	remaining: 1.29s
# 57:	total: 1.74s	remaining: 1.26s
# 58:	total: 1.77s	remaining: 1.23s
# 59:	total: 1.8s	remaining: 1.2s
# 60:	total: 1.83s	remaining: 1.17s
# 61:	total: 1.86s	remaining: 1.14s
# 62:	total: 1.89s	remaining: 1.11s
# 63:	total: 1.92s	remaining: 1.08s
# 64:	total: 1.95s	remaining: 1.05s
# 65:	total: 1.98s	remaining: 1.02s
# 66:	total: 2.01s	remaining: 989ms
# 67:	total: 2.04s	remaining: 959ms
# 68:	total: 2.07s	remaining: 929ms
# 69:	total: 2.09s	remaining: 898ms
# 70:	total: 2.13s	remaining: 869ms
# 71:	total: 2.16s	remaining: 839ms
# 72:	total: 2.19s	remaining: 808ms
# 73:	total: 2.22s	remaining: 779ms
# 74:	total: 2.25s	remaining: 749ms
# 75:	total: 2.28s	remaining: 719ms
# 76:	total: 2.31s	remaining: 689ms
# 77:	total: 2.33s	remaining: 659ms
# 78:	total: 2.37s	remaining: 629ms
# 79:	total: 2.4s	remaining: 599ms
# 80:	total: 2.42s	remaining: 569ms
# 81:	total: 2.46s	remaining: 539ms
# 82:	total: 2.48s	remaining: 509ms
# 83:	total: 2.51s	remaining: 479ms
# 84:	total: 2.54s	remaining: 449ms
# 85:	total: 2.57s	remaining: 419ms
# 86:	total: 2.6s	remaining: 389ms
# 87:	total: 2.63s	remaining: 358ms
# 88:	total: 2.66s	remaining: 328ms
# 89:	total: 2.69s	remaining: 298ms
# 90:	total: 2.71s	remaining: 268ms
# 91:	total: 2.74s	remaining: 239ms
# 92:	total: 2.78s	remaining: 209ms
# 93:	total: 2.81s	remaining: 179ms
# 94:	total: 2.83s	remaining: 149ms
# 95:	total: 2.86s	remaining: 119ms
# 96:	total: 2.89s	remaining: 89.4ms
# 97:	total: 2.92s	remaining: 59.6ms
# 98:	total: 2.95s	remaining: 29.8ms
# 99:	total: 2.98s	remaining: 0us
# 0:	total: 29.9ms	remaining: 2.96s
# 1:	total: 60.3ms	remaining: 2.96s
# 2:	total: 90.6ms	remaining: 2.93s
# 3:	total: 122ms	remaining: 2.92s
# 4:	total: 149ms	remaining: 2.82s
# 5:	total: 180ms	remaining: 2.82s
# 6:	total: 209ms	remaining: 2.77s
# 7:	total: 238ms	remaining: 2.74s
# 8:	total: 267ms	remaining: 2.7s
# 9:	total: 298ms	remaining: 2.69s
# 10:	total: 330ms	remaining: 2.67s
# 11:	total: 360ms	remaining: 2.64s
# 12:	total: 389ms	remaining: 2.6s
# 13:	total: 418ms	remaining: 2.57s
# 14:	total: 449ms	remaining: 2.54s
# 15:	total: 481ms	remaining: 2.52s
# 16:	total: 510ms	remaining: 2.49s
# 17:	total: 542ms	remaining: 2.47s
# 18:	total: 573ms	remaining: 2.44s
# 19:	total: 606ms	remaining: 2.42s
# 20:	total: 634ms	remaining: 2.38s
# 21:	total: 664ms	remaining: 2.35s
# 22:	total: 696ms	remaining: 2.33s
# 23:	total: 727ms	remaining: 2.3s
# 24:	total: 761ms	remaining: 2.28s
# 25:	total: 792ms	remaining: 2.25s
# 26:	total: 821ms	remaining: 2.22s
# 27:	total: 848ms	remaining: 2.18s
# 28:	total: 879ms	remaining: 2.15s
# 29:	total: 909ms	remaining: 2.12s
# 30:	total: 939ms	remaining: 2.09s
# 31:	total: 969ms	remaining: 2.06s
# 32:	total: 996ms	remaining: 2.02s
# 33:	total: 1.03s	remaining: 1.99s
# 34:	total: 1.06s	remaining: 1.96s
# 35:	total: 1.08s	remaining: 1.93s
# 36:	total: 1.12s	remaining: 1.9s
# 37:	total: 1.14s	remaining: 1.87s
# 38:	total: 1.17s	remaining: 1.83s
# 39:	total: 1.2s	remaining: 1.8s
# 40:	total: 1.23s	remaining: 1.77s
# 41:	total: 1.26s	remaining: 1.74s
# 42:	total: 1.29s	remaining: 1.71s
# 43:	total: 1.32s	remaining: 1.69s
# 44:	total: 1.35s	remaining: 1.66s
# 45:	total: 1.39s	remaining: 1.63s
# 46:	total: 1.42s	remaining: 1.6s
# 47:	total: 1.45s	remaining: 1.57s
# 48:	total: 1.48s	remaining: 1.54s
# 49:	total: 1.51s	remaining: 1.51s
# 50:	total: 1.54s	remaining: 1.48s
# 51:	total: 1.57s	remaining: 1.45s
# 52:	total: 1.6s	remaining: 1.42s
# 53:	total: 1.63s	remaining: 1.39s
# 54:	total: 1.66s	remaining: 1.36s
# 55:	total: 1.69s	remaining: 1.32s
# 56:	total: 1.72s	remaining: 1.29s
# 57:	total: 1.75s	remaining: 1.27s
# 58:	total: 1.78s	remaining: 1.23s
# 59:	total: 1.81s	remaining: 1.2s
# 60:	total: 1.83s	remaining: 1.17s
# 61:	total: 1.86s	remaining: 1.14s
# 62:	total: 1.89s	remaining: 1.11s
# 63:	total: 1.92s	remaining: 1.08s
# 64:	total: 1.95s	remaining: 1.05s
# 65:	total: 1.98s	remaining: 1.02s
# 66:	total: 2.01s	remaining: 991ms
# 67:	total: 2.04s	remaining: 962ms
# 68:	total: 2.07s	remaining: 932ms
# 69:	total: 2.11s	remaining: 903ms
# 70:	total: 2.13s	remaining: 872ms
# 71:	total: 2.16s	remaining: 841ms
# 72:	total: 2.19s	remaining: 811ms
# 73:	total: 2.22s	remaining: 781ms
# 74:	total: 2.25s	remaining: 751ms
# 75:	total: 2.28s	remaining: 721ms
# 76:	total: 2.31s	remaining: 692ms
# 77:	total: 2.34s	remaining: 661ms
# 78:	total: 2.38s	remaining: 632ms
# 79:	total: 2.41s	remaining: 602ms
# 80:	total: 2.44s	remaining: 572ms
# 81:	total: 2.47s	remaining: 542ms
# 82:	total: 2.5s	remaining: 511ms
# 83:	total: 2.52s	remaining: 481ms
# 84:	total: 2.56s	remaining: 452ms
# 85:	total: 2.59s	remaining: 421ms
# 86:	total: 2.62s	remaining: 391ms
# 87:	total: 2.64s	remaining: 361ms
# 88:	total: 2.67s	remaining: 331ms
# 89:	total: 2.71s	remaining: 301ms
# 90:	total: 2.74s	remaining: 271ms
# 91:	total: 2.77s	remaining: 241ms
# 92:	total: 2.79s	remaining: 210ms
# 93:	total: 2.82s	remaining: 180ms
# 94:	total: 2.86s	remaining: 150ms
# 95:	total: 2.89s	remaining: 120ms
# 96:	total: 2.92s	remaining: 90.2ms
# 97:	total: 2.94s	remaining: 60.1ms
# 98:	total: 2.97s	remaining: 30ms
# 99:	total: 3s	remaining: 0us
# 0:	total: 28.1ms	remaining: 2.78s
# 1:	total: 53.3ms	remaining: 2.61s
# 2:	total: 82.5ms	remaining: 2.67s
# 3:	total: 113ms	remaining: 2.72s
# 4:	total: 141ms	remaining: 2.68s
# 5:	total: 172ms	remaining: 2.7s
# 6:	total: 200ms	remaining: 2.65s
# 7:	total: 231ms	remaining: 2.65s
# 8:	total: 258ms	remaining: 2.61s
# 9:	total: 289ms	remaining: 2.6s
# 10:	total: 320ms	remaining: 2.59s
# 11:	total: 349ms	remaining: 2.56s
# 12:	total: 379ms	remaining: 2.53s
# 13:	total: 409ms	remaining: 2.51s
# 14:	total: 436ms	remaining: 2.47s
# 15:	total: 463ms	remaining: 2.43s
# 16:	total: 483ms	remaining: 2.36s
# 17:	total: 513ms	remaining: 2.34s
# 18:	total: 544ms	remaining: 2.32s
# 19:	total: 572ms	remaining: 2.29s
# 20:	total: 602ms	remaining: 2.26s
# 21:	total: 627ms	remaining: 2.22s
# 22:	total: 657ms	remaining: 2.2s
# 23:	total: 684ms	remaining: 2.17s
# 24:	total: 715ms	remaining: 2.14s
# 25:	total: 742ms	remaining: 2.11s
# 26:	total: 774ms	remaining: 2.09s
# 27:	total: 806ms	remaining: 2.07s
# 28:	total: 836ms	remaining: 2.04s
# 29:	total: 866ms	remaining: 2.02s
# 30:	total: 896ms	remaining: 1.99s
# 31:	total: 924ms	remaining: 1.96s
# 32:	total: 954ms	remaining: 1.94s
# 33:	total: 980ms	remaining: 1.9s
# 34:	total: 1s	remaining: 1.86s
# 35:	total: 1.03s	remaining: 1.83s
# 36:	total: 1.05s	remaining: 1.8s
# 37:	total: 1.08s	remaining: 1.77s
# 38:	total: 1.11s	remaining: 1.74s
# 39:	total: 1.14s	remaining: 1.71s
# 40:	total: 1.17s	remaining: 1.68s
# 41:	total: 1.2s	remaining: 1.65s
# 42:	total: 1.23s	remaining: 1.63s
# 43:	total: 1.25s	remaining: 1.59s
# 44:	total: 1.28s	remaining: 1.56s
# 45:	total: 1.3s	remaining: 1.53s
# 46:	total: 1.33s	remaining: 1.5s
# 47:	total: 1.36s	remaining: 1.48s
# 48:	total: 1.39s	remaining: 1.45s
# 49:	total: 1.42s	remaining: 1.42s
# 50:	total: 1.45s	remaining: 1.39s
# 51:	total: 1.48s	remaining: 1.37s
# 52:	total: 1.51s	remaining: 1.34s
# 53:	total: 1.54s	remaining: 1.32s
# 54:	total: 1.57s	remaining: 1.29s
# 55:	total: 1.61s	remaining: 1.26s
# 56:	total: 1.64s	remaining: 1.24s
# 57:	total: 1.67s	remaining: 1.21s
# 58:	total: 1.7s	remaining: 1.18s
# 59:	total: 1.73s	remaining: 1.15s
# 60:	total: 1.76s	remaining: 1.13s
# 61:	total: 1.79s	remaining: 1.1s
# 62:	total: 1.82s	remaining: 1.07s
# 63:	total: 1.85s	remaining: 1.04s
# 64:	total: 1.89s	remaining: 1.01s
# 65:	total: 1.92s	remaining: 987ms
# 66:	total: 1.94s	remaining: 958ms
# 67:	total: 1.97s	remaining: 928ms
# 68:	total: 2s	remaining: 898ms
# 69:	total: 2.02s	remaining: 868ms
# 70:	total: 2.05s	remaining: 838ms
# 71:	total: 2.08s	remaining: 809ms
# 72:	total: 2.11s	remaining: 781ms
# 73:	total: 2.14s	remaining: 752ms
# 74:	total: 2.17s	remaining: 724ms
# 75:	total: 2.2s	remaining: 695ms
# 76:	total: 2.22s	remaining: 663ms
# 77:	total: 2.25s	remaining: 634ms
# 78:	total: 2.28s	remaining: 605ms
# 79:	total: 2.31s	remaining: 577ms
# 80:	total: 2.34s	remaining: 548ms
# 81:	total: 2.37s	remaining: 520ms
# 82:	total: 2.4s	remaining: 492ms
# 83:	total: 2.43s	remaining: 462ms
# 84:	total: 2.46s	remaining: 434ms
# 85:	total: 2.49s	remaining: 405ms
# 86:	total: 2.52s	remaining: 376ms
# 87:	total: 2.55s	remaining: 347ms
# 88:	total: 2.58s	remaining: 318ms
# 89:	total: 2.6s	remaining: 289ms
# 90:	total: 2.63s	remaining: 261ms
# 91:	total: 2.67s	remaining: 232ms
# 92:	total: 2.7s	remaining: 203ms
# 93:	total: 2.72s	remaining: 174ms
# 94:	total: 2.75s	remaining: 145ms
# 95:	total: 2.78s	remaining: 116ms
# 96:	total: 2.81s	remaining: 86.8ms
# 97:	total: 2.84s	remaining: 57.9ms
# 98:	total: 2.87s	remaining: 29ms
# 99:	total: 2.89s	remaining: 0us
# 0:	total: 31.5ms	remaining: 3.12s
# 1:	total: 61.3ms	remaining: 3s
# 2:	total: 91ms	remaining: 2.94s
# 3:	total: 119ms	remaining: 2.85s
# 4:	total: 149ms	remaining: 2.84s
# 5:	total: 180ms	remaining: 2.82s
# 6:	total: 209ms	remaining: 2.78s
# 7:	total: 237ms	remaining: 2.73s
# 8:	total: 267ms	remaining: 2.7s
# 9:	total: 298ms	remaining: 2.68s
# 10:	total: 327ms	remaining: 2.64s
# 11:	total: 355ms	remaining: 2.6s
# 12:	total: 386ms	remaining: 2.58s
# 13:	total: 414ms	remaining: 2.54s
# 14:	total: 442ms	remaining: 2.5s
# 15:	total: 470ms	remaining: 2.47s
# 16:	total: 501ms	remaining: 2.44s
# 17:	total: 530ms	remaining: 2.41s
# 18:	total: 558ms	remaining: 2.38s
# 19:	total: 584ms	remaining: 2.34s
# 20:	total: 614ms	remaining: 2.31s
# 21:	total: 643ms	remaining: 2.28s
# 22:	total: 674ms	remaining: 2.25s
# 23:	total: 704ms	remaining: 2.23s
# 24:	total: 734ms	remaining: 2.2s
# 25:	total: 761ms	remaining: 2.17s
# 26:	total: 790ms	remaining: 2.14s
# 27:	total: 821ms	remaining: 2.11s
# 28:	total: 849ms	remaining: 2.08s
# 29:	total: 878ms	remaining: 2.05s
# 30:	total: 909ms	remaining: 2.02s
# 31:	total: 939ms	remaining: 2s
# 32:	total: 969ms	remaining: 1.97s
# 33:	total: 998ms	remaining: 1.94s
# 34:	total: 1.02s	remaining: 1.9s
# 35:	total: 1.06s	remaining: 1.88s
# 36:	total: 1.08s	remaining: 1.85s
# 37:	total: 1.11s	remaining: 1.81s
# 38:	total: 1.14s	remaining: 1.78s
# 39:	total: 1.17s	remaining: 1.75s
# 40:	total: 1.2s	remaining: 1.72s
# 41:	total: 1.23s	remaining: 1.69s
# 42:	total: 1.25s	remaining: 1.66s
# 43:	total: 1.28s	remaining: 1.63s
# 44:	total: 1.31s	remaining: 1.6s
# 45:	total: 1.34s	remaining: 1.57s
# 46:	total: 1.37s	remaining: 1.54s
# 47:	total: 1.39s	remaining: 1.51s
# 48:	total: 1.42s	remaining: 1.48s
# 49:	total: 1.45s	remaining: 1.45s
# 50:	total: 1.48s	remaining: 1.42s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.34s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.22s
# 58:	total: 1.72s	remaining: 1.2s
# 59:	total: 1.75s	remaining: 1.17s
# 60:	total: 1.78s	remaining: 1.14s
# 61:	total: 1.81s	remaining: 1.11s
# 62:	total: 1.83s	remaining: 1.08s
# 63:	total: 1.86s	remaining: 1.05s
# 64:	total: 1.89s	remaining: 1.02s
# 65:	total: 1.92s	remaining: 988ms
# 66:	total: 1.95s	remaining: 960ms
# 67:	total: 1.98s	remaining: 931ms
# 68:	total: 2.01s	remaining: 902ms
# 69:	total: 2.04s	remaining: 873ms
# 70:	total: 2.06s	remaining: 844ms
# 71:	total: 2.09s	remaining: 814ms
# 72:	total: 2.12s	remaining: 786ms
# 73:	total: 2.15s	remaining: 757ms
# 74:	total: 2.19s	remaining: 730ms
# 75:	total: 2.22s	remaining: 701ms
# 76:	total: 2.25s	remaining: 672ms
# 77:	total: 2.28s	remaining: 642ms
# 78:	total: 2.31s	remaining: 614ms
# 79:	total: 2.34s	remaining: 584ms
# 80:	total: 2.36s	remaining: 554ms
# 81:	total: 2.39s	remaining: 525ms
# 82:	total: 2.42s	remaining: 496ms
# 83:	total: 2.45s	remaining: 467ms
# 84:	total: 2.48s	remaining: 437ms
# 85:	total: 2.51s	remaining: 408ms
# 86:	total: 2.54s	remaining: 379ms
# 87:	total: 2.56s	remaining: 350ms
# 88:	total: 2.59s	remaining: 321ms
# 89:	total: 2.62s	remaining: 291ms
# 90:	total: 2.65s	remaining: 262ms
# 91:	total: 2.68s	remaining: 233ms
# 92:	total: 2.71s	remaining: 204ms
# 93:	total: 2.74s	remaining: 175ms
# 94:	total: 2.77s	remaining: 146ms
# 95:	total: 2.8s	remaining: 117ms
# 96:	total: 2.83s	remaining: 87.4ms
# 97:	total: 2.86s	remaining: 58.3ms
# 98:	total: 2.88s	remaining: 29.1ms
# 99:	total: 2.91s	remaining: 0us
# 0:	total: 29.8ms	remaining: 2.95s
# 1:	total: 60.6ms	remaining: 2.97s
# 2:	total: 89.3ms	remaining: 2.89s
# 3:	total: 118ms	remaining: 2.83s
# 4:	total: 149ms	remaining: 2.83s
# 5:	total: 179ms	remaining: 2.81s
# 6:	total: 208ms	remaining: 2.76s
# 7:	total: 236ms	remaining: 2.71s
# 8:	total: 264ms	remaining: 2.67s
# 9:	total: 292ms	remaining: 2.63s
# 10:	total: 320ms	remaining: 2.59s
# 11:	total: 349ms	remaining: 2.56s
# 12:	total: 380ms	remaining: 2.54s
# 13:	total: 409ms	remaining: 2.51s
# 14:	total: 438ms	remaining: 2.48s
# 15:	total: 469ms	remaining: 2.46s
# 16:	total: 498ms	remaining: 2.43s
# 17:	total: 528ms	remaining: 2.4s
# 18:	total: 556ms	remaining: 2.37s
# 19:	total: 585ms	remaining: 2.34s
# 20:	total: 616ms	remaining: 2.32s
# 21:	total: 645ms	remaining: 2.29s
# 22:	total: 673ms	remaining: 2.25s
# 23:	total: 704ms	remaining: 2.23s
# 24:	total: 730ms	remaining: 2.19s
# 25:	total: 759ms	remaining: 2.16s
# 26:	total: 788ms	remaining: 2.13s
# 27:	total: 815ms	remaining: 2.1s
# 28:	total: 848ms	remaining: 2.08s
# 29:	total: 877ms	remaining: 2.04s
# 30:	total: 906ms	remaining: 2.02s
# 31:	total: 934ms	remaining: 1.98s
# 32:	total: 962ms	remaining: 1.95s
# 33:	total: 989ms	remaining: 1.92s
# 34:	total: 1.02s	remaining: 1.89s
# 35:	total: 1.04s	remaining: 1.86s
# 36:	total: 1.08s	remaining: 1.83s
# 37:	total: 1.11s	remaining: 1.8s
# 38:	total: 1.14s	remaining: 1.77s
# 39:	total: 1.17s	remaining: 1.75s
# 40:	total: 1.19s	remaining: 1.72s
# 41:	total: 1.22s	remaining: 1.69s
# 42:	total: 1.25s	remaining: 1.66s
# 43:	total: 1.28s	remaining: 1.63s
# 44:	total: 1.31s	remaining: 1.6s
# 45:	total: 1.34s	remaining: 1.57s
# 46:	total: 1.37s	remaining: 1.55s
# 47:	total: 1.4s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.49s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.49s	remaining: 1.43s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.34s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.22s
# 58:	total: 1.72s	remaining: 1.19s
# 59:	total: 1.75s	remaining: 1.17s
# 60:	total: 1.78s	remaining: 1.14s
# 61:	total: 1.8s	remaining: 1.1s
# 62:	total: 1.83s	remaining: 1.07s
# 63:	total: 1.85s	remaining: 1.04s
# 64:	total: 1.87s	remaining: 1.01s
# 65:	total: 1.9s	remaining: 980ms
# 66:	total: 1.93s	remaining: 952ms
# 67:	total: 1.96s	remaining: 923ms
# 68:	total: 1.99s	remaining: 893ms
# 69:	total: 2.02s	remaining: 865ms
# 70:	total: 2.05s	remaining: 836ms
# 71:	total: 2.08s	remaining: 809ms
# 72:	total: 2.11s	remaining: 780ms
# 73:	total: 2.14s	remaining: 752ms
# 74:	total: 2.17s	remaining: 724ms
# 75:	total: 2.2s	remaining: 694ms
# 76:	total: 2.23s	remaining: 665ms
# 77:	total: 2.25s	remaining: 636ms
# 78:	total: 2.28s	remaining: 606ms
# 79:	total: 2.31s	remaining: 578ms
# 80:	total: 2.34s	remaining: 549ms
# 81:	total: 2.37s	remaining: 521ms
# 82:	total: 2.4s	remaining: 492ms
# 83:	total: 2.43s	remaining: 463ms
# 84:	total: 2.46s	remaining: 434ms
# 85:	total: 2.49s	remaining: 405ms
# 86:	total: 2.52s	remaining: 376ms
# 87:	total: 2.54s	remaining: 347ms
# 88:	total: 2.57s	remaining: 318ms
# 89:	total: 2.6s	remaining: 289ms
# 90:	total: 2.63s	remaining: 260ms
# 91:	total: 2.66s	remaining: 231ms
# 92:	total: 2.69s	remaining: 202ms
# 93:	total: 2.72s	remaining: 173ms
# 94:	total: 2.74s	remaining: 144ms
# 95:	total: 2.77s	remaining: 116ms
# 96:	total: 2.8s	remaining: 86.7ms
# 97:	total: 2.83s	remaining: 57.8ms
# 98:	total: 2.86s	remaining: 28.9ms
# 99:	total: 2.88s	remaining: 0us
# 0:	total: 30.6ms	remaining: 3.03s
# 1:	total: 59.4ms	remaining: 2.91s
# 2:	total: 89.8ms	remaining: 2.9s
# 3:	total: 118ms	remaining: 2.84s
# 4:	total: 146ms	remaining: 2.77s
# 5:	total: 175ms	remaining: 2.73s
# 6:	total: 206ms	remaining: 2.73s
# 7:	total: 235ms	remaining: 2.71s
# 8:	total: 265ms	remaining: 2.68s
# 9:	total: 293ms	remaining: 2.63s
# 10:	total: 322ms	remaining: 2.6s
# 11:	total: 352ms	remaining: 2.58s
# 12:	total: 383ms	remaining: 2.56s
# 13:	total: 414ms	remaining: 2.54s
# 14:	total: 445ms	remaining: 2.52s
# 15:	total: 471ms	remaining: 2.47s
# 16:	total: 501ms	remaining: 2.44s
# 17:	total: 530ms	remaining: 2.41s
# 18:	total: 559ms	remaining: 2.38s
# 19:	total: 590ms	remaining: 2.36s
# 20:	total: 620ms	remaining: 2.33s
# 21:	total: 651ms	remaining: 2.31s
# 22:	total: 679ms	remaining: 2.27s
# 23:	total: 710ms	remaining: 2.25s
# 24:	total: 740ms	remaining: 2.22s
# 25:	total: 770ms	remaining: 2.19s
# 26:	total: 799ms	remaining: 2.16s
# 27:	total: 824ms	remaining: 2.12s
# 28:	total: 852ms	remaining: 2.08s
# 29:	total: 880ms	remaining: 2.05s
# 30:	total: 908ms	remaining: 2.02s
# 31:	total: 938ms	remaining: 1.99s
# 32:	total: 968ms	remaining: 1.96s
# 33:	total: 996ms	remaining: 1.93s
# 34:	total: 1.02s	remaining: 1.9s
# 35:	total: 1.05s	remaining: 1.87s
# 36:	total: 1.08s	remaining: 1.84s
# 37:	total: 1.11s	remaining: 1.81s
# 38:	total: 1.14s	remaining: 1.78s
# 39:	total: 1.17s	remaining: 1.75s
# 40:	total: 1.2s	remaining: 1.72s
# 41:	total: 1.23s	remaining: 1.7s
# 42:	total: 1.26s	remaining: 1.67s
# 43:	total: 1.29s	remaining: 1.64s
# 44:	total: 1.32s	remaining: 1.61s
# 45:	total: 1.35s	remaining: 1.58s
# 46:	total: 1.38s	remaining: 1.55s
# 47:	total: 1.41s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.49s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.49s	remaining: 1.43s
# 51:	total: 1.52s	remaining: 1.4s
# 52:	total: 1.55s	remaining: 1.37s
# 53:	total: 1.58s	remaining: 1.35s
# 54:	total: 1.61s	remaining: 1.32s
# 55:	total: 1.64s	remaining: 1.29s
# 56:	total: 1.67s	remaining: 1.26s
# 57:	total: 1.69s	remaining: 1.23s
# 58:	total: 1.71s	remaining: 1.19s
# 59:	total: 1.74s	remaining: 1.16s
# 60:	total: 1.77s	remaining: 1.13s
# 61:	total: 1.8s	remaining: 1.1s
# 62:	total: 1.83s	remaining: 1.07s
# 63:	total: 1.85s	remaining: 1.04s
# 64:	total: 1.88s	remaining: 1.01s
# 65:	total: 1.91s	remaining: 984ms
# 66:	total: 1.94s	remaining: 955ms
# 67:	total: 1.97s	remaining: 927ms
# 68:	total: 2s	remaining: 898ms
# 69:	total: 2.02s	remaining: 867ms
# 70:	total: 2.05s	remaining: 837ms
# 71:	total: 2.08s	remaining: 808ms
# 72:	total: 2.1s	remaining: 778ms
# 73:	total: 2.13s	remaining: 749ms
# 74:	total: 2.16s	remaining: 721ms
# 75:	total: 2.19s	remaining: 692ms
# 76:	total: 2.22s	remaining: 664ms
# 77:	total: 2.25s	remaining: 635ms
# 78:	total: 2.28s	remaining: 607ms
# 79:	total: 2.31s	remaining: 578ms
# 80:	total: 2.34s	remaining: 550ms
# 81:	total: 2.37s	remaining: 521ms
# 82:	total: 2.4s	remaining: 492ms
# 83:	total: 2.43s	remaining: 463ms
# 84:	total: 2.46s	remaining: 434ms
# 85:	total: 2.49s	remaining: 405ms
# 86:	total: 2.51s	remaining: 375ms
# 87:	total: 2.54s	remaining: 346ms
# 88:	total: 2.57s	remaining: 318ms
# 89:	total: 2.6s	remaining: 289ms
# 90:	total: 2.63s	remaining: 260ms
# 91:	total: 2.66s	remaining: 231ms
# 92:	total: 2.69s	remaining: 203ms
# 93:	total: 2.72s	remaining: 173ms
# 94:	total: 2.74s	remaining: 144ms
# 95:	total: 2.77s	remaining: 116ms
# 96:	total: 2.8s	remaining: 86.7ms
# 97:	total: 2.84s	remaining: 57.9ms
# 98:	total: 2.87s	remaining: 28.9ms
# 99:	total: 2.9s	remaining: 0us
# 0:	total: 27.3ms	remaining: 2.71s
# 1:	total: 54.3ms	remaining: 2.66s
# 2:	total: 81.4ms	remaining: 2.63s
# 3:	total: 111ms	remaining: 2.67s
# 4:	total: 139ms	remaining: 2.65s
# 5:	total: 170ms	remaining: 2.66s
# 6:	total: 198ms	remaining: 2.63s
# 7:	total: 228ms	remaining: 2.62s
# 8:	total: 255ms	remaining: 2.58s
# 9:	total: 292ms	remaining: 2.63s
# 10:	total: 323ms	remaining: 2.61s
# 11:	total: 351ms	remaining: 2.58s
# 12:	total: 381ms	remaining: 2.55s
# 13:	total: 411ms	remaining: 2.53s
# 14:	total: 440ms	remaining: 2.5s
# 15:	total: 469ms	remaining: 2.46s
# 16:	total: 498ms	remaining: 2.43s
# 17:	total: 526ms	remaining: 2.4s
# 18:	total: 555ms	remaining: 2.37s
# 19:	total: 585ms	remaining: 2.34s
# 20:	total: 615ms	remaining: 2.31s
# 21:	total: 644ms	remaining: 2.28s
# 22:	total: 674ms	remaining: 2.25s
# 23:	total: 703ms	remaining: 2.23s
# 24:	total: 733ms	remaining: 2.2s
# 25:	total: 762ms	remaining: 2.17s
# 26:	total: 792ms	remaining: 2.14s
# 27:	total: 823ms	remaining: 2.12s
# 28:	total: 850ms	remaining: 2.08s
# 29:	total: 877ms	remaining: 2.05s
# 30:	total: 904ms	remaining: 2.01s
# 31:	total: 934ms	remaining: 1.98s
# 32:	total: 965ms	remaining: 1.96s
# 33:	total: 992ms	remaining: 1.93s
# 34:	total: 1.02s	remaining: 1.9s
# 35:	total: 1.05s	remaining: 1.86s
# 36:	total: 1.08s	remaining: 1.84s
# 37:	total: 1.11s	remaining: 1.81s
# 38:	total: 1.14s	remaining: 1.78s
# 39:	total: 1.17s	remaining: 1.75s
# 40:	total: 1.2s	remaining: 1.73s
# 41:	total: 1.23s	remaining: 1.7s
# 42:	total: 1.25s	remaining: 1.66s
# 43:	total: 1.28s	remaining: 1.64s
# 44:	total: 1.32s	remaining: 1.61s
# 45:	total: 1.35s	remaining: 1.58s
# 46:	total: 1.38s	remaining: 1.55s
# 47:	total: 1.4s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.49s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.48s	remaining: 1.43s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.34s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.22s
# 58:	total: 1.71s	remaining: 1.19s
# 59:	total: 1.75s	remaining: 1.16s
# 60:	total: 1.78s	remaining: 1.14s
# 61:	total: 1.8s	remaining: 1.1s
# 62:	total: 1.83s	remaining: 1.07s
# 63:	total: 1.85s	remaining: 1.04s
# 64:	total: 1.88s	remaining: 1.01s
# 65:	total: 1.91s	remaining: 983ms
# 66:	total: 1.94s	remaining: 954ms
# 67:	total: 1.97s	remaining: 925ms
# 68:	total: 1.99s	remaining: 896ms
# 69:	total: 2.02s	remaining: 867ms
# 70:	total: 2.05s	remaining: 838ms
# 71:	total: 2.08s	remaining: 809ms
# 72:	total: 2.11s	remaining: 780ms
# 73:	total: 2.14s	remaining: 753ms
# 74:	total: 2.17s	remaining: 722ms
# 75:	total: 2.19s	remaining: 693ms
# 76:	total: 2.23s	remaining: 665ms
# 77:	total: 2.25s	remaining: 636ms
# 78:	total: 2.28s	remaining: 607ms
# 79:	total: 2.31s	remaining: 578ms
# 80:	total: 2.34s	remaining: 549ms
# 81:	total: 2.37s	remaining: 520ms
# 82:	total: 2.4s	remaining: 491ms
# 83:	total: 2.42s	remaining: 462ms
# 84:	total: 2.45s	remaining: 433ms
# 85:	total: 2.48s	remaining: 404ms
# 86:	total: 2.51s	remaining: 375ms
# 87:	total: 2.54s	remaining: 347ms
# 88:	total: 2.57s	remaining: 318ms
# 89:	total: 2.6s	remaining: 289ms
# 90:	total: 2.63s	remaining: 260ms
# 91:	total: 2.66s	remaining: 231ms
# 92:	total: 2.69s	remaining: 202ms
# 93:	total: 2.72s	remaining: 173ms
# 94:	total: 2.75s	remaining: 145ms
# 95:	total: 2.78s	remaining: 116ms
# 96:	total: 2.81s	remaining: 86.8ms
# 97:	total: 2.83s	remaining: 57.9ms
# 98:	total: 2.87s	remaining: 29ms
# 99:	total: 2.9s	remaining: 0us
# 0:	total: 30.1ms	remaining: 2.98s
# 1:	total: 58.2ms	remaining: 2.85s
# 2:	total: 87.3ms	remaining: 2.82s
# 3:	total: 117ms	remaining: 2.81s
# 4:	total: 147ms	remaining: 2.79s
# 5:	total: 178ms	remaining: 2.78s
# 6:	total: 207ms	remaining: 2.75s
# 7:	total: 239ms	remaining: 2.75s
# 8:	total: 267ms	remaining: 2.7s
# 9:	total: 295ms	remaining: 2.65s
# 10:	total: 322ms	remaining: 2.61s
# 11:	total: 352ms	remaining: 2.58s
# 12:	total: 383ms	remaining: 2.56s
# 13:	total: 412ms	remaining: 2.53s
# 14:	total: 441ms	remaining: 2.5s
# 15:	total: 472ms	remaining: 2.48s
# 16:	total: 502ms	remaining: 2.45s
# 17:	total: 532ms	remaining: 2.42s
# 18:	total: 562ms	remaining: 2.4s
# 19:	total: 592ms	remaining: 2.37s
# 20:	total: 621ms	remaining: 2.34s
# 21:	total: 652ms	remaining: 2.31s
# 22:	total: 683ms	remaining: 2.29s
# 23:	total: 711ms	remaining: 2.25s
# 24:	total: 739ms	remaining: 2.22s
# 25:	total: 769ms	remaining: 2.19s
# 26:	total: 800ms	remaining: 2.16s
# 27:	total: 829ms	remaining: 2.13s
# 28:	total: 858ms	remaining: 2.1s
# 29:	total: 890ms	remaining: 2.08s
# 30:	total: 920ms	remaining: 2.05s
# 31:	total: 947ms	remaining: 2.01s
# 32:	total: 974ms	remaining: 1.98s
# 33:	total: 1s	remaining: 1.95s
# 34:	total: 1.03s	remaining: 1.92s
# 35:	total: 1.06s	remaining: 1.89s
# 36:	total: 1.09s	remaining: 1.86s
# 37:	total: 1.12s	remaining: 1.83s
# 38:	total: 1.15s	remaining: 1.8s
# 39:	total: 1.18s	remaining: 1.77s
# 40:	total: 1.21s	remaining: 1.74s
# 41:	total: 1.24s	remaining: 1.71s
# 42:	total: 1.26s	remaining: 1.68s
# 43:	total: 1.29s	remaining: 1.64s
# 44:	total: 1.32s	remaining: 1.61s
# 45:	total: 1.35s	remaining: 1.58s
# 46:	total: 1.38s	remaining: 1.55s
# 47:	total: 1.41s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.49s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.49s	remaining: 1.43s
# 51:	total: 1.52s	remaining: 1.41s
# 52:	total: 1.55s	remaining: 1.38s
# 53:	total: 1.58s	remaining: 1.35s
# 54:	total: 1.61s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.23s
# 58:	total: 1.72s	remaining: 1.2s
# 59:	total: 1.75s	remaining: 1.17s
# 60:	total: 1.78s	remaining: 1.14s
# 61:	total: 1.81s	remaining: 1.11s
# 62:	total: 1.84s	remaining: 1.08s
# 63:	total: 1.87s	remaining: 1.05s
# 64:	total: 1.9s	remaining: 1.02s
# 65:	total: 1.93s	remaining: 996ms
# 66:	total: 1.96s	remaining: 966ms
# 67:	total: 1.99s	remaining: 936ms
# 68:	total: 2.02s	remaining: 907ms
# 69:	total: 2.05s	remaining: 877ms
# 70:	total: 2.08s	remaining: 848ms
# 71:	total: 2.1s	remaining: 818ms
# 72:	total: 2.13s	remaining: 789ms
# 73:	total: 2.16s	remaining: 760ms
# 74:	total: 2.19s	remaining: 730ms
# 75:	total: 2.22s	remaining: 701ms
# 76:	total: 2.25s	remaining: 672ms
# 77:	total: 2.28s	remaining: 643ms
# 78:	total: 2.31s	remaining: 614ms
# 79:	total: 2.33s	remaining: 583ms
# 80:	total: 2.36s	remaining: 554ms
# 81:	total: 2.39s	remaining: 525ms
# 82:	total: 2.42s	remaining: 496ms
# 83:	total: 2.45s	remaining: 467ms
# 84:	total: 2.47s	remaining: 437ms
# 85:	total: 2.5s	remaining: 406ms
# 86:	total: 2.52s	remaining: 377ms
# 87:	total: 2.54s	remaining: 347ms
# 88:	total: 2.56s	remaining: 317ms
# 89:	total: 2.59s	remaining: 288ms
# 90:	total: 2.61s	remaining: 258ms
# 91:	total: 2.64s	remaining: 230ms
# 92:	total: 2.66s	remaining: 201ms
# 93:	total: 2.69s	remaining: 172ms
# 94:	total: 2.72s	remaining: 143ms
# 95:	total: 2.74s	remaining: 114ms
# 96:	total: 2.77s	remaining: 85.6ms
# 97:	total: 2.79s	remaining: 56.9ms
# 98:	total: 2.81s	remaining: 28.4ms
# 99:	total: 2.84s	remaining: 0us
# cross_val_score:  0.82
# precision score is  0.68
# recall_score is  0.3822
# f1 score is  0.49
# ROC AUC is  0.67

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(clfCB, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 0:	total: 28.4ms	remaining: 2.81s
# 1:	total: 57.6ms	remaining: 2.82s
# 2:	total: 86.2ms	remaining: 2.79s
# 3:	total: 116ms	remaining: 2.79s
# 4:	total: 146ms	remaining: 2.77s
# 5:	total: 174ms	remaining: 2.72s
# 6:	total: 205ms	remaining: 2.72s
# 7:	total: 232ms	remaining: 2.67s
# 8:	total: 261ms	remaining: 2.64s
# 9:	total: 290ms	remaining: 2.61s
# 10:	total: 320ms	remaining: 2.59s
# 11:	total: 350ms	remaining: 2.57s
# 12:	total: 381ms	remaining: 2.55s
# 13:	total: 410ms	remaining: 2.52s
# 14:	total: 437ms	remaining: 2.48s
# 15:	total: 468ms	remaining: 2.45s
# 16:	total: 496ms	remaining: 2.42s
# 17:	total: 524ms	remaining: 2.39s
# 18:	total: 553ms	remaining: 2.36s
# 19:	total: 583ms	remaining: 2.33s
# 20:	total: 612ms	remaining: 2.3s
# 21:	total: 641ms	remaining: 2.27s
# 22:	total: 672ms	remaining: 2.25s
# 23:	total: 700ms	remaining: 2.21s
# 24:	total: 731ms	remaining: 2.19s
# 25:	total: 762ms	remaining: 2.17s
# 26:	total: 791ms	remaining: 2.14s
# 27:	total: 820ms	remaining: 2.11s
# 28:	total: 851ms	remaining: 2.08s
# 29:	total: 881ms	remaining: 2.06s
# 30:	total: 911ms	remaining: 2.03s
# 31:	total: 941ms	remaining: 2s
# 32:	total: 970ms	remaining: 1.97s
# 33:	total: 1s	remaining: 1.94s
# 34:	total: 1.03s	remaining: 1.91s
# 35:	total: 1.06s	remaining: 1.88s
# 36:	total: 1.09s	remaining: 1.85s
# 37:	total: 1.11s	remaining: 1.82s
# 38:	total: 1.14s	remaining: 1.79s
# 39:	total: 1.17s	remaining: 1.76s
# 40:	total: 1.2s	remaining: 1.73s
# 41:	total: 1.23s	remaining: 1.7s
# 42:	total: 1.26s	remaining: 1.67s
# 43:	total: 1.29s	remaining: 1.64s
# 44:	total: 1.32s	remaining: 1.61s
# 45:	total: 1.34s	remaining: 1.58s
# 46:	total: 1.37s	remaining: 1.55s
# 47:	total: 1.4s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.48s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.48s	remaining: 1.43s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.33s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.22s
# 58:	total: 1.72s	remaining: 1.19s
# 59:	total: 1.75s	remaining: 1.16s
# 60:	total: 1.77s	remaining: 1.13s
# 61:	total: 1.8s	remaining: 1.1s
# 62:	total: 1.83s	remaining: 1.08s
# 63:	total: 1.86s	remaining: 1.05s
# 64:	total: 1.9s	remaining: 1.02s
# 65:	total: 1.92s	remaining: 990ms
# 66:	total: 1.95s	remaining: 961ms
# 67:	total: 1.98s	remaining: 933ms
# 68:	total: 2.01s	remaining: 905ms
# 69:	total: 2.04s	remaining: 876ms
# 70:	total: 2.07s	remaining: 846ms
# 71:	total: 2.1s	remaining: 817ms
# 72:	total: 2.13s	remaining: 788ms
# 73:	total: 2.16s	remaining: 759ms
# 74:	total: 2.19s	remaining: 730ms
# 75:	total: 2.22s	remaining: 701ms
# 76:	total: 2.25s	remaining: 672ms
# 77:	total: 2.28s	remaining: 642ms
# 78:	total: 2.3s	remaining: 613ms
# 79:	total: 2.33s	remaining: 583ms
# 80:	total: 2.36s	remaining: 554ms
# 81:	total: 2.39s	remaining: 525ms
# 82:	total: 2.42s	remaining: 496ms
# 83:	total: 2.45s	remaining: 467ms
# 84:	total: 2.48s	remaining: 438ms
# 85:	total: 2.51s	remaining: 409ms
# 86:	total: 2.54s	remaining: 380ms
# 87:	total: 2.57s	remaining: 351ms
# 88:	total: 2.6s	remaining: 322ms
# 89:	total: 2.63s	remaining: 292ms
# 90:	total: 2.66s	remaining: 263ms
# 91:	total: 2.68s	remaining: 233ms
# 92:	total: 2.71s	remaining: 204ms
# 93:	total: 2.74s	remaining: 175ms
# 94:	total: 2.77s	remaining: 146ms
# 95:	total: 2.8s	remaining: 117ms
# 96:	total: 2.83s	remaining: 87.4ms
# 97:	total: 2.85s	remaining: 58.2ms
# 98:	total: 2.88s	remaining: 29.1ms
# 99:	total: 2.91s	remaining: 0us
# 0:	total: 30.1ms	remaining: 2.98s
# 1:	total: 57.6ms	remaining: 2.82s
# 2:	total: 88.5ms	remaining: 2.86s
# 3:	total: 115ms	remaining: 2.76s
# 4:	total: 146ms	remaining: 2.78s
# 5:	total: 174ms	remaining: 2.72s
# 6:	total: 204ms	remaining: 2.71s
# 7:	total: 234ms	remaining: 2.69s
# 8:	total: 267ms	remaining: 2.7s
# 9:	total: 297ms	remaining: 2.67s
# 10:	total: 324ms	remaining: 2.62s
# 11:	total: 357ms	remaining: 2.62s
# 12:	total: 386ms	remaining: 2.58s
# 13:	total: 415ms	remaining: 2.55s
# 14:	total: 442ms	remaining: 2.5s
# 15:	total: 470ms	remaining: 2.47s
# 16:	total: 500ms	remaining: 2.44s
# 17:	total: 530ms	remaining: 2.41s
# 18:	total: 557ms	remaining: 2.38s
# 19:	total: 589ms	remaining: 2.36s
# 20:	total: 618ms	remaining: 2.32s
# 21:	total: 647ms	remaining: 2.29s
# 22:	total: 677ms	remaining: 2.27s
# 23:	total: 708ms	remaining: 2.24s
# 24:	total: 737ms	remaining: 2.21s
# 25:	total: 767ms	remaining: 2.18s
# 26:	total: 795ms	remaining: 2.15s
# 27:	total: 819ms	remaining: 2.1s
# 28:	total: 850ms	remaining: 2.08s
# 29:	total: 879ms	remaining: 2.05s
# 30:	total: 909ms	remaining: 2.02s
# 31:	total: 937ms	remaining: 1.99s
# 32:	total: 967ms	remaining: 1.96s
# 33:	total: 998ms	remaining: 1.94s
# 34:	total: 1.02s	remaining: 1.9s
# 35:	total: 1.05s	remaining: 1.86s
# 36:	total: 1.08s	remaining: 1.83s
# 37:	total: 1.1s	remaining: 1.8s
# 38:	total: 1.14s	remaining: 1.77s
# 39:	total: 1.16s	remaining: 1.75s
# 40:	total: 1.19s	remaining: 1.71s
# 41:	total: 1.22s	remaining: 1.68s
# 42:	total: 1.25s	remaining: 1.66s
# 43:	total: 1.28s	remaining: 1.63s
# 44:	total: 1.3s	remaining: 1.59s
# 45:	total: 1.34s	remaining: 1.57s
# 46:	total: 1.37s	remaining: 1.54s
# 47:	total: 1.4s	remaining: 1.51s
# 48:	total: 1.42s	remaining: 1.48s
# 49:	total: 1.45s	remaining: 1.45s
# 50:	total: 1.48s	remaining: 1.42s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.33s
# 54:	total: 1.59s	remaining: 1.3s
# 55:	total: 1.62s	remaining: 1.27s
# 56:	total: 1.65s	remaining: 1.24s
# 57:	total: 1.68s	remaining: 1.22s
# 58:	total: 1.71s	remaining: 1.19s
# 59:	total: 1.74s	remaining: 1.16s
# 60:	total: 1.77s	remaining: 1.13s
# 61:	total: 1.8s	remaining: 1.1s
# 62:	total: 1.83s	remaining: 1.07s
# 63:	total: 1.86s	remaining: 1.04s
# 64:	total: 1.89s	remaining: 1.01s
# 65:	total: 1.91s	remaining: 986ms
# 66:	total: 1.94s	remaining: 957ms
# 67:	total: 1.97s	remaining: 926ms
# 68:	total: 2s	remaining: 897ms
# 69:	total: 2.02s	remaining: 868ms
# 70:	total: 2.05s	remaining: 839ms
# 71:	total: 2.08s	remaining: 810ms
# 72:	total: 2.11s	remaining: 782ms
# 73:	total: 2.14s	remaining: 753ms
# 74:	total: 2.17s	remaining: 725ms
# 75:	total: 2.2s	remaining: 696ms
# 76:	total: 2.23s	remaining: 668ms
# 77:	total: 2.27s	remaining: 639ms
# 78:	total: 2.29s	remaining: 610ms
# 79:	total: 2.32s	remaining: 581ms
# 80:	total: 2.35s	remaining: 552ms
# 81:	total: 2.38s	remaining: 523ms
# 82:	total: 2.41s	remaining: 494ms
# 83:	total: 2.44s	remaining: 465ms
# 84:	total: 2.47s	remaining: 435ms
# 85:	total: 2.5s	remaining: 407ms
# 86:	total: 2.52s	remaining: 377ms
# 87:	total: 2.56s	remaining: 349ms
# 88:	total: 2.58s	remaining: 320ms
# 89:	total: 2.61s	remaining: 290ms
# 90:	total: 2.64s	remaining: 261ms
# 91:	total: 2.67s	remaining: 232ms
# 92:	total: 2.7s	remaining: 203ms
# 93:	total: 2.72s	remaining: 174ms
# 94:	total: 2.75s	remaining: 145ms
# 95:	total: 2.78s	remaining: 116ms
# 96:	total: 2.81s	remaining: 87ms
# 97:	total: 2.84s	remaining: 58ms
# 98:	total: 2.87s	remaining: 29ms
# 99:	total: 2.9s	remaining: 0us
# 0:	total: 28.1ms	remaining: 2.78s
# 1:	total: 59.6ms	remaining: 2.92s
# 2:	total: 89.7ms	remaining: 2.9s
# 3:	total: 122ms	remaining: 2.92s
# 4:	total: 150ms	remaining: 2.85s
# 5:	total: 172ms	remaining: 2.7s
# 6:	total: 201ms	remaining: 2.67s
# 7:	total: 229ms	remaining: 2.63s
# 8:	total: 257ms	remaining: 2.6s
# 9:	total: 288ms	remaining: 2.6s
# 10:	total: 318ms	remaining: 2.57s
# 11:	total: 348ms	remaining: 2.55s
# 12:	total: 377ms	remaining: 2.52s
# 13:	total: 408ms	remaining: 2.5s
# 14:	total: 439ms	remaining: 2.49s
# 15:	total: 470ms	remaining: 2.47s
# 16:	total: 499ms	remaining: 2.44s
# 17:	total: 525ms	remaining: 2.39s
# 18:	total: 555ms	remaining: 2.37s
# 19:	total: 586ms	remaining: 2.34s
# 20:	total: 615ms	remaining: 2.31s
# 21:	total: 648ms	remaining: 2.29s
# 22:	total: 683ms	remaining: 2.29s
# 23:	total: 717ms	remaining: 2.27s
# 24:	total: 752ms	remaining: 2.25s
# 25:	total: 784ms	remaining: 2.23s
# 26:	total: 815ms	remaining: 2.2s
# 27:	total: 848ms	remaining: 2.18s
# 28:	total: 880ms	remaining: 2.15s
# 29:	total: 909ms	remaining: 2.12s
# 30:	total: 936ms	remaining: 2.08s
# 31:	total: 969ms	remaining: 2.06s
# 32:	total: 997ms	remaining: 2.02s
# 33:	total: 1.03s	remaining: 1.99s
# 34:	total: 1.06s	remaining: 1.96s
# 35:	total: 1.08s	remaining: 1.93s
# 36:	total: 1.11s	remaining: 1.9s
# 37:	total: 1.14s	remaining: 1.86s
# 38:	total: 1.17s	remaining: 1.83s
# 39:	total: 1.2s	remaining: 1.8s
# 40:	total: 1.23s	remaining: 1.77s
# 41:	total: 1.26s	remaining: 1.74s
# 42:	total: 1.29s	remaining: 1.71s
# 43:	total: 1.31s	remaining: 1.67s
# 44:	total: 1.34s	remaining: 1.64s
# 45:	total: 1.37s	remaining: 1.61s
# 46:	total: 1.4s	remaining: 1.58s
# 47:	total: 1.43s	remaining: 1.55s
# 48:	total: 1.46s	remaining: 1.52s
# 49:	total: 1.49s	remaining: 1.49s
# 50:	total: 1.52s	remaining: 1.46s
# 51:	total: 1.55s	remaining: 1.43s
# 52:	total: 1.58s	remaining: 1.4s
# 53:	total: 1.61s	remaining: 1.37s
# 54:	total: 1.64s	remaining: 1.34s
# 55:	total: 1.67s	remaining: 1.31s
# 56:	total: 1.7s	remaining: 1.28s
# 57:	total: 1.73s	remaining: 1.25s
# 58:	total: 1.76s	remaining: 1.22s
# 59:	total: 1.79s	remaining: 1.2s
# 60:	total: 1.82s	remaining: 1.17s
# 61:	total: 1.85s	remaining: 1.13s
# 62:	total: 1.88s	remaining: 1.1s
# 63:	total: 1.91s	remaining: 1.07s
# 64:	total: 1.94s	remaining: 1.04s
# 65:	total: 1.97s	remaining: 1.01s
# 66:	total: 2s	remaining: 983ms
# 67:	total: 2.02s	remaining: 951ms
# 68:	total: 2.05s	remaining: 921ms
# 69:	total: 2.08s	remaining: 892ms
# 70:	total: 2.1s	remaining: 860ms
# 71:	total: 2.14s	remaining: 832ms
# 72:	total: 2.17s	remaining: 802ms
# 73:	total: 2.19s	remaining: 769ms
# 74:	total: 2.22s	remaining: 740ms
# 75:	total: 2.25s	remaining: 711ms
# 76:	total: 2.28s	remaining: 682ms
# 77:	total: 2.3s	remaining: 650ms
# 78:	total: 2.33s	remaining: 620ms
# 79:	total: 2.36s	remaining: 590ms
# 80:	total: 2.38s	remaining: 557ms
# 81:	total: 2.4s	remaining: 528ms
# 82:	total: 2.43s	remaining: 498ms
# 83:	total: 2.46s	remaining: 469ms
# 84:	total: 2.49s	remaining: 440ms
# 85:	total: 2.52s	remaining: 410ms
# 86:	total: 2.55s	remaining: 381ms
# 87:	total: 2.57s	remaining: 350ms
# 88:	total: 2.6s	remaining: 321ms
# 89:	total: 2.63s	remaining: 292ms
# 90:	total: 2.65s	remaining: 263ms
# 91:	total: 2.69s	remaining: 234ms
# 92:	total: 2.72s	remaining: 205ms
# 93:	total: 2.75s	remaining: 175ms
# 94:	total: 2.78s	remaining: 146ms
# 95:	total: 2.8s	remaining: 117ms
# 96:	total: 2.83s	remaining: 87.6ms
# 97:	total: 2.86s	remaining: 58.4ms
# 98:	total: 2.89s	remaining: 29.2ms
# 99:	total: 2.92s	remaining: 0us
# 0:	total: 29.6ms	remaining: 2.93s
# 1:	total: 56.5ms	remaining: 2.77s
# 2:	total: 83.3ms	remaining: 2.69s
# 3:	total: 113ms	remaining: 2.7s
# 4:	total: 141ms	remaining: 2.69s
# 5:	total: 163ms	remaining: 2.55s
# 6:	total: 192ms	remaining: 2.55s
# 7:	total: 223ms	remaining: 2.56s
# 8:	total: 253ms	remaining: 2.56s
# 9:	total: 281ms	remaining: 2.53s
# 10:	total: 311ms	remaining: 2.52s
# 11:	total: 341ms	remaining: 2.5s
# 12:	total: 371ms	remaining: 2.48s
# 13:	total: 399ms	remaining: 2.45s
# 14:	total: 430ms	remaining: 2.44s
# 15:	total: 463ms	remaining: 2.43s
# 16:	total: 493ms	remaining: 2.4s
# 17:	total: 524ms	remaining: 2.38s
# 18:	total: 551ms	remaining: 2.35s
# 19:	total: 577ms	remaining: 2.31s
# 20:	total: 606ms	remaining: 2.28s
# 21:	total: 636ms	remaining: 2.26s
# 22:	total: 662ms	remaining: 2.22s
# 23:	total: 692ms	remaining: 2.19s
# 24:	total: 720ms	remaining: 2.16s
# 25:	total: 752ms	remaining: 2.14s
# 26:	total: 780ms	remaining: 2.11s
# 27:	total: 807ms	remaining: 2.08s
# 28:	total: 840ms	remaining: 2.06s
# 29:	total: 871ms	remaining: 2.03s
# 30:	total: 898ms	remaining: 2s
# 31:	total: 927ms	remaining: 1.97s
# 32:	total: 957ms	remaining: 1.94s
# 33:	total: 988ms	remaining: 1.92s
# 34:	total: 1.02s	remaining: 1.89s
# 35:	total: 1.05s	remaining: 1.86s
# 36:	total: 1.08s	remaining: 1.83s
# 37:	total: 1.1s	remaining: 1.8s
# 38:	total: 1.13s	remaining: 1.77s
# 39:	total: 1.16s	remaining: 1.75s
# 40:	total: 1.19s	remaining: 1.72s
# 41:	total: 1.22s	remaining: 1.69s
# 42:	total: 1.25s	remaining: 1.66s
# 43:	total: 1.28s	remaining: 1.64s
# 44:	total: 1.32s	remaining: 1.61s
# 45:	total: 1.35s	remaining: 1.58s
# 46:	total: 1.37s	remaining: 1.54s
# 47:	total: 1.4s	remaining: 1.51s
# 48:	total: 1.43s	remaining: 1.48s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.49s	remaining: 1.43s
# 51:	total: 1.51s	remaining: 1.4s
# 52:	total: 1.54s	remaining: 1.37s
# 53:	total: 1.57s	remaining: 1.34s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.23s
# 58:	total: 1.72s	remaining: 1.19s
# 59:	total: 1.74s	remaining: 1.16s
# 60:	total: 1.77s	remaining: 1.13s
# 61:	total: 1.8s	remaining: 1.11s
# 62:	total: 1.83s	remaining: 1.08s
# 63:	total: 1.86s	remaining: 1.05s
# 64:	total: 1.89s	remaining: 1.02s
# 65:	total: 1.92s	remaining: 990ms
# 66:	total: 1.95s	remaining: 961ms
# 67:	total: 1.98s	remaining: 933ms
# 68:	total: 2.01s	remaining: 902ms
# 69:	total: 2.03s	remaining: 872ms
# 70:	total: 2.06s	remaining: 841ms
# 71:	total: 2.09s	remaining: 812ms
# 72:	total: 2.12s	remaining: 784ms
# 73:	total: 2.15s	remaining: 755ms
# 74:	total: 2.18s	remaining: 726ms
# 75:	total: 2.21s	remaining: 697ms
# 76:	total: 2.24s	remaining: 669ms
# 77:	total: 2.27s	remaining: 640ms
# 78:	total: 2.3s	remaining: 611ms
# 79:	total: 2.33s	remaining: 583ms
# 80:	total: 2.36s	remaining: 554ms
# 81:	total: 2.39s	remaining: 524ms
# 82:	total: 2.42s	remaining: 495ms
# 83:	total: 2.44s	remaining: 466ms
# 84:	total: 2.48s	remaining: 437ms
# 85:	total: 2.5s	remaining: 408ms
# 86:	total: 2.54s	remaining: 379ms
# 87:	total: 2.56s	remaining: 350ms
# 88:	total: 2.59s	remaining: 320ms
# 89:	total: 2.63s	remaining: 292ms
# 90:	total: 2.66s	remaining: 263ms
# 91:	total: 2.69s	remaining: 234ms
# 92:	total: 2.71s	remaining: 204ms
# 93:	total: 2.74s	remaining: 175ms
# 94:	total: 2.78s	remaining: 146ms
# 95:	total: 2.81s	remaining: 117ms
# 96:	total: 2.83s	remaining: 87.7ms
# 97:	total: 2.87s	remaining: 58.5ms
# 98:	total: 2.89s	remaining: 29.2ms
# 99:	total: 2.92s	remaining: 0us
# 0:	total: 29.6ms	remaining: 2.93s
# 1:	total: 60.6ms	remaining: 2.97s
# 2:	total: 90.3ms	remaining: 2.92s
# 3:	total: 118ms	remaining: 2.83s
# 4:	total: 148ms	remaining: 2.81s
# 5:	total: 180ms	remaining: 2.81s
# 6:	total: 211ms	remaining: 2.81s
# 7:	total: 245ms	remaining: 2.82s
# 8:	total: 274ms	remaining: 2.77s
# 9:	total: 301ms	remaining: 2.71s
# 10:	total: 331ms	remaining: 2.68s
# 11:	total: 363ms	remaining: 2.66s
# 12:	total: 392ms	remaining: 2.62s
# 13:	total: 421ms	remaining: 2.58s
# 14:	total: 449ms	remaining: 2.54s
# 15:	total: 481ms	remaining: 2.53s
# 16:	total: 515ms	remaining: 2.51s
# 17:	total: 545ms	remaining: 2.48s
# 18:	total: 573ms	remaining: 2.44s
# 19:	total: 602ms	remaining: 2.41s
# 20:	total: 630ms	remaining: 2.37s
# 21:	total: 660ms	remaining: 2.34s
# 22:	total: 691ms	remaining: 2.31s
# 23:	total: 723ms	remaining: 2.29s
# 24:	total: 752ms	remaining: 2.25s
# 25:	total: 782ms	remaining: 2.23s
# 26:	total: 812ms	remaining: 2.2s
# 27:	total: 840ms	remaining: 2.16s
# 28:	total: 855ms	remaining: 2.09s
# 29:	total: 888ms	remaining: 2.07s
# 30:	total: 919ms	remaining: 2.04s
# 31:	total: 947ms	remaining: 2.01s
# 32:	total: 977ms	remaining: 1.98s
# 33:	total: 1s	remaining: 1.95s
# 34:	total: 1.03s	remaining: 1.92s
# 35:	total: 1.06s	remaining: 1.89s
# 36:	total: 1.09s	remaining: 1.86s
# 37:	total: 1.12s	remaining: 1.83s
# 38:	total: 1.16s	remaining: 1.81s
# 39:	total: 1.19s	remaining: 1.78s
# 40:	total: 1.22s	remaining: 1.75s
# 41:	total: 1.25s	remaining: 1.72s
# 42:	total: 1.27s	remaining: 1.69s
# 43:	total: 1.3s	remaining: 1.65s
# 44:	total: 1.31s	remaining: 1.61s
# 45:	total: 1.34s	remaining: 1.58s
# 46:	total: 1.38s	remaining: 1.55s
# 47:	total: 1.4s	remaining: 1.52s
# 48:	total: 1.43s	remaining: 1.49s
# 49:	total: 1.46s	remaining: 1.46s
# 50:	total: 1.49s	remaining: 1.43s
# 51:	total: 1.52s	remaining: 1.4s
# 52:	total: 1.55s	remaining: 1.37s
# 53:	total: 1.58s	remaining: 1.34s
# 54:	total: 1.6s	remaining: 1.31s
# 55:	total: 1.63s	remaining: 1.28s
# 56:	total: 1.66s	remaining: 1.25s
# 57:	total: 1.69s	remaining: 1.23s
# 58:	total: 1.72s	remaining: 1.2s
# 59:	total: 1.75s	remaining: 1.17s
# 60:	total: 1.78s	remaining: 1.14s
# 61:	total: 1.81s	remaining: 1.11s
# 62:	total: 1.84s	remaining: 1.08s
# 63:	total: 1.87s	remaining: 1.05s
# 64:	total: 1.9s	remaining: 1.02s
# 65:	total: 1.93s	remaining: 995ms
# 66:	total: 1.96s	remaining: 966ms
# 67:	total: 1.99s	remaining: 937ms
# 68:	total: 2.02s	remaining: 908ms
# 69:	total: 2.05s	remaining: 880ms
# 70:	total: 2.09s	remaining: 852ms
# 71:	total: 2.11s	remaining: 822ms
# 72:	total: 2.14s	remaining: 793ms
# 73:	total: 2.17s	remaining: 764ms
# 74:	total: 2.19s	remaining: 732ms
# 75:	total: 2.22s	remaining: 702ms
# 76:	total: 2.25s	remaining: 672ms
# 77:	total: 2.28s	remaining: 642ms
# 78:	total: 2.31s	remaining: 613ms
# 79:	total: 2.32s	remaining: 581ms
# 80:	total: 2.35s	remaining: 552ms
# 81:	total: 2.38s	remaining: 523ms
# 82:	total: 2.41s	remaining: 494ms
# 83:	total: 2.44s	remaining: 465ms
# 84:	total: 2.47s	remaining: 436ms
# 85:	total: 2.5s	remaining: 407ms
# 86:	total: 2.53s	remaining: 378ms
# 87:	total: 2.56s	remaining: 349ms
# 88:	total: 2.59s	remaining: 320ms
# 89:	total: 2.62s	remaining: 291ms
# 90:	total: 2.65s	remaining: 262ms
# 91:	total: 2.68s	remaining: 233ms
# 92:	total: 2.71s	remaining: 204ms
# 93:	total: 2.74s	remaining: 175ms
# 94:	total: 2.77s	remaining: 146ms
# 95:	total: 2.79s	remaining: 116ms
# 96:	total: 2.82s	remaining: 87.2ms
# 97:	total: 2.85s	remaining: 58.1ms
# 98:	total: 2.88s	remaining: 29.1ms
# 99:	total: 2.91s	remaining: 0us
# 5-fold cross-validation f1 results: 0.47694559052767344

# %% [markdown]
# # Decision Tree

# %%
# Create Decision Tree classifer object
clfTR = DecisionTreeClassifier()

# Train Decision Tree Classifer
clfTR = clfTR.fit(X_train_oversampled,y_train_oversampled)

#Predict the response for test dataset
y_pred = clfTR.predict(X_test)

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfTR, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, y_pred).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, y_pred).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, y_pred).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, y_pred).round(2))
# Out:
# cross_val_score:  0.74
# precision score is  0.38
# recall_score is  0.4202
# f1 score is  0.396
# ROC AUC is  0.61

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82      4710
#            1       0.38      0.42      0.40      1290
#
#    micro avg       0.72      0.72      0.73      6000
#    macro avg       0.61      0.61      0.61      6000
# weighted avg       0.74      0.72      0.73      6000

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(clfTR, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.406157681710574

# %%
#graph.write_png('diabetes.png')
#Image(graph.create_png())

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clfTR, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols, class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-672dcffad7de> in <module>()
#      10 export_graphviz(clfTR, out_file=dot_data,
#      11                 filled=True, rounded=True,
# ---> 12                 special_characters=True,feature_names = feature_cols, class_names=['0','1'])
#      13 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#
# NameError: name 'feature_cols' is not defined

# %% [markdown]
# # Support Vector Machine (SVM)
# ## Unable to run on Jupyter Classroom

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clfSVM = svm.SVC(kernel='linear',cache_size = 7000) # Linear Kernel

# %%
#Train the model using the training sets
clfSVM.fit(X_train_oversampled,y_train_oversampled)

# %%
#Predict the response for test dataset
y_predSVM = clfSVM.predict(X_test)

# %%
# Cross Validation
cross_val_score_SVM = cross_val_score(clfSVM, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_SVM.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, y_predSVM).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, y_predSVM).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, y_predSVM).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, y_predSVM).round(2))

# %% [markdown]
# # GaussianNB

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
clfGNB = gnb.fit(X_train_oversampled,y_train_oversampled)

#Predict the response for test dataset
y_predgnb = gnb.predict(X_test)

# %%
# Cross Validation
cross_val_score_GNB = cross_val_score(clfGNB, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_GNB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, y_predgnb).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, y_predgnb).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, y_predgnb).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, y_predgnb).round(2))
# Out:
# cross_val_score:  0.3
# precision score is  0.22
# recall_score is  0.9419
# f1 score is  0.363
# ROC AUC is  0.53

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(clfGNB, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation f1 results: {np.mean(results)}")
# Out:
# 5-fold cross-validation f1 results: 0.368046436809087

# %% [markdown]
# # ENSEMBLE
# ## Unable to run on Jupyter Classroom

# %%
# Bagged Decision Trees for Classification - necessary dependencies

from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# AdaBoost Classification

from sklearn.ensemble import AdaBoostClassifier
seed = 2019
num_trees = 70
kfold = model_selection.KFold(n_splits=10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X, y, cv=kfold)
print(results.mean())
# Out:
# 0.8158666666666667

# %%
# Voting Ensemble for Classification

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

# %%
kfold = model_selection.KFold(n_splits=10, random_state=seed)
# create the sub models
estimators = []
model1 = LogisticRegression()
estimators.append(('logistic', model1))

# %%
model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))

# %%
model3 = SVC()
estimators.append(('svm', model3))

# %%
# create the ensemble model
ensemble = VotingClassifier(estimators)
results = model_selection.cross_val_score(ensemble, X, y, cv=kfold)
print(results.mean())

# %%
# Confusion Matrix
cmLR = confusion_matrix(y_test, predLR)
cmSVC = confusion_matrix(y_test, predSVC)
cmKNN = confusion_matrix(y_test, predKNN)
cmRF = confusion_matrix(y_test, predRF)
cmTR = confusion_matrix(y_test, y_pred)
cmLGB = confusion_matrix(y_test, predLGB)
cmCB = confusion_matrix(y_test, predCB)


# Confusion Matrix List
cmList = [cmLR, cmSVC,cmKNN, cmRF,cmTR,  cmLGB, cmCB]
cmTitle = ['Logistic Regression','Support Vector Machines classifier','K Nearest Neighbors','Random Forest',"Classification Tree", 'LightGB','CatGBM', None]
i = 0
plt.figure()
fig, ax = plt.subplots(2,4, num = 6, figsize = (30,10))
for cm in cmList:
    i += 1
    plt.subplot(2,4,i)
    plt.title(cmTitle[i-1])
    sns.heatmap(cm, annot = True, cmap = 'YlGnBu')
plt.show()
plt.savefig('matrix.png');

# %%
X.columns

# %%
continuous = X.loc[:,['LIMIT_BAL','BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
       'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
       'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']]

# %%
categorical = X.loc[:,['AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5',
       'PAY_6','SEX_Female', 'SEX_Male',
       'EDUCATION_Graduate School', 'EDUCATION_Other', 'EDUCATION_University',
       'MARRIAGE_Married', 'MARRIAGE_Non-married']]

# %%
continuous.head()

# %%
categorical.head()

# %%
m = continuous

# %%
scaler = MinMaxScaler(feature_range=(0, 1), copy=True)

# %%
continuous = scaler.fit_transform(continuous)

# %%
continuous = pd.DataFrame(continuous, columns = m.columns)

# %%
continuous.head()

# %%
categorical.head()

# %%
X = pd.concat([continuous, categorical],axis = 0 )

# %%
X.head().T

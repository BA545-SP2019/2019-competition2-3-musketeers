# %%
# !git clone https://github.com/BA545-SP2019/2019-competition2-3-musketeers.git
# Out:
# Cloning into '2019-competition2-3-musketeers'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 664 (delta 80), reused 89 (delta 30), pack-reused 521
# Receiving objects: 100% (664/664), 20.43 MiB | 16.42 MiB/s, done.
# Resolving deltas: 100% (423/423), done.

# %%
# %cd 2019-competition2-3-musketeers/Kevin/
# Out:
# /content/2019-competition2-3-musketeers/Kevin

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/f4/44/60f82c97d1caa98752c7da2c1681cab5c7a390a0fdd3a55fac672b321cac/scikit_optimize-0.5.2-py2.py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 25.6MB/s
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.20.3)
# Installing collected packages: scikit-optimize
# Successfully installed scikit-optimize-0.5.2

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from Modules import *
sns.set()
# %matplotlib inline
import imblearn
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold

# %%
#read in the data; data formated weird with extra column, 
#use only data we need
data = pd.read_csv('Data/Final_trimmed_sequential_data.csv')
df = data.iloc[:, 1:]
y = df['Y']

df.head()
# Out:
#    AGE  Y  SEX_Female  SEX_Male  EDUCATION_Graduate School  EDUCATION_Other  \
# 0   24  1           1         0                          0                0
# 1   26  1           1         0                          0                0
# 2   34  0           1         0                          0                0
# 3   37  0           1         0                          0                0
# 4   57  0           0         1                          0                0
#
#    EDUCATION_University  MARRIAGE_Married  MARRIAGE_Non-married  \
# 0                     1                 1                     0
# 1                     1                 0                     1
# 2                     1                 0                     1
# 3                     1                 1                     0
# 4                     1                 1                     0
#
#    PERCENT_OF_LIMIT_BAL1  ...  PAY_4_Other  PAY_4_more_than_two_month_late  \
# 0               0.195650  ...            0                               0
# 1               0.022350  ...            1                               0
# 2               0.308011  ...            1                               0
# 3               0.899800  ...            1                               0
# 4               0.132340  ...            1                               0
#
#    PAY_4_on_time  PAY_4_one_month_late  PAY_5_Other  \
# 0              1                     0            1
# 1              0                     0            1
# 2              0                     0            1
# 3              0                     0            1
# 4              0                     0            1
#
#    PAY_5_more_than_two_month_late  PAY_5_on_time  PAY_6_Other  \
# 0                               0              0            1
# 1                               0              0            0
# 2                               0              0            1
# 3                               0              0            1
# 4                               0              0            1
#
#    PAY_6_more_than_two_month_late  PAY_6_on_time
# 0                               0              0
# 1                               1              0
# 2                               0              0
# 3                               0              0
# 4                               0              0
#
# [5 rows x 53 columns]

# %% [markdown]
# Using scikit-optimize for BayesSearchCV of xgboost model

# %%
#xgboost settings 
# SETTINGS - CHANGE THESE TO GET SOMETHING MEANINGFUL
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

Train_data, test_data = train_test_split(df, test_size = 0.2, random_state = 2019)

ITERATIONS = 200
target = 'Y'
predictors = [x for x in Train_data.columns if x not in [target]]

# %% [markdown]
# # Build our skopt object
#
# Here, we'll use the BayesSearchCV class of skopt to efficiently search through the hyperparameter space to find optimal values for these hyperparameters. This acts as a drop in replacement for sklearn's GridSearchCV and RandomSearchCV. We'll compare how well this does to the `XGBosst_tuning` notebook results.

# %%
# First, we specify the model we'd like to tune,
# then, we define the search spaces for each hyperparameter,
# in the structure of (minimum, maximum, format of range)
from skopt import BayesSearchCV
bayes_cv_tuner = BayesSearchCV(
    estimator = xgb.XGBClassifier(
        objective = 'binary:logistic',
        eval_metric = 'auc',
        silent=1,
        tree_method='approx'
    ),
    search_spaces = {
        'learning_rate': (0.01, 1.0, 'log-uniform'),
        'min_child_weight': (0, 10),
        'max_depth': (1, 50),
        'max_delta_step': (0, 20),
        'subsample': (0.01, 1.0, 'uniform'),
        'colsample_bytree': (0.01, 1.0, 'uniform'),
        'colsample_bylevel': (0.01, 1.0, 'uniform'),
        'reg_lambda': (1e-9, 1000, 'log-uniform'),
        'reg_alpha': (1e-9, 1.0, 'log-uniform'),
        'gamma': (1e-9, 0.5, 'log-uniform'),
        'min_child_weight': (0, 5),
        'n_estimators': (50, 100),
        'scale_pos_weight': (1e-6, 500, 'log-uniform')
    },    
    scoring = 'roc_auc',
    cv = StratifiedKFold(
        n_splits=3,
        shuffle=True,
        random_state=2019
    ),
    n_jobs = -1,
    n_iter = ITERATIONS,   
    verbose = 0,
    refit = True,
    random_state = 2019
)

# %%
# helper function to see outputs 

def status_print(optim_result):
    """Status callback durring bayesian hyperparameter search"""
    
    # Get all the models tested so far in DataFrame format
    all_models = pd.DataFrame(bayes_cv_tuner.cv_results_)    
    
    # Get current parameters and the best parameters    
    best_params = pd.Series(bayes_cv_tuner.best_params_)
    print('Model #{}\nBest ROC-AUC: {}\nBest params: {}\n'.format(
        len(all_models),
        np.round(bayes_cv_tuner.best_score_, 4),
        bayes_cv_tuner.best_params_
    ))
    
    # Save all model results
    clf_name = bayes_cv_tuner.estimator.__class__.__name__
    all_models.to_csv(clf_name+"_cv_results.csv")

# %%
#test it out

result = bayes_cv_tuner.fit(Train_data[predictors].values, Train_data[target].values, callback=status_print)
# Out:
# Model #1
# Best ROC-AUC: 0.6426
# Best params: {'colsample_bylevel': 0.6209161581689696, 'colsample_bytree': 0.9543275764819017, 'gamma': 0.019306137883859383, 'learning_rate': 0.03133533072824358, 'max_delta_step': 1, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 57, 'reg_alpha': 0.00031596262458470826, 'reg_lambda': 0.18102189707922706, 'scale_pos_weight': 0.02920585956428371, 'subsample': 0.5387531676662357}
#
# Model #2
# Best ROC-AUC: 0.6426
# Best params: {'colsample_bylevel': 0.6209161581689696, 'colsample_bytree': 0.9543275764819017, 'gamma': 0.019306137883859383, 'learning_rate': 0.03133533072824358, 'max_delta_step': 1, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 57, 'reg_alpha': 0.00031596262458470826, 'reg_lambda': 0.18102189707922706, 'scale_pos_weight': 0.02920585956428371, 'subsample': 0.5387531676662357}
#
# Model #3
# Best ROC-AUC: 0.6426
# Best params: {'colsample_bylevel': 0.6209161581689696, 'colsample_bytree': 0.9543275764819017, 'gamma': 0.019306137883859383, 'learning_rate': 0.03133533072824358, 'max_delta_step': 1, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 57, 'reg_alpha': 0.00031596262458470826, 'reg_lambda': 0.18102189707922706, 'scale_pos_weight': 0.02920585956428371, 'subsample': 0.5387531676662357}
#
# Model #4
# Best ROC-AUC: 0.7615
# Best params: {'colsample_bylevel': 0.8506120087489681, 'colsample_bytree': 0.4353668066570514, 'gamma': 0.015303832638663898, 'learning_rate': 0.010901757755696722, 'max_delta_step': 10, 'max_depth': 48, 'min_child_weight': 1, 'n_estimators': 55, 'reg_alpha': 1.655534184728137e-07, 'reg_lambda': 0.15007254540719694, 'scale_pos_weight': 24.621318956691496, 'subsample': 0.6461085825512918}
#
# Model #5
# Best ROC-AUC: 0.762
# Best params: {'colsample_bylevel': 0.7407235113866864, 'colsample_bytree': 0.30302192306386905, 'gamma': 4.0417655790730556e-09, 'learning_rate': 0.6623364991828246, 'max_delta_step': 0, 'max_depth': 8, 'min_child_weight': 2, 'n_estimators': 72, 'reg_alpha': 0.00017704608225498113, 'reg_lambda': 4.595598535151634e-08, 'scale_pos_weight': 0.00800649942542308, 'subsample': 0.9241329838280757}
#
# Model #6
# Best ROC-AUC: 0.7662
# Best params: {'colsample_bylevel': 0.7911279142754272, 'colsample_bytree': 0.7859503866108143, 'gamma': 1.0268342887939747e-09, 'learning_rate': 0.6487822362455956, 'max_delta_step': 11, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 53, 'reg_alpha': 3.16377703179663e-07, 'reg_lambda': 0.00026033144618566533, 'scale_pos_weight': 1.1413921386499382, 'subsample': 0.9221867930191819}
#
# Model #7
# Best ROC-AUC: 0.7679
# Best params: {'colsample_bylevel': 0.06446277637668772, 'colsample_bytree': 0.4087994013853717, 'gamma': 6.785440128234311e-07, 'learning_rate': 0.023746541021187735, 'max_delta_step': 18, 'max_depth': 23, 'min_child_weight': 4, 'n_estimators': 69, 'reg_alpha': 0.00042782574992984306, 'reg_lambda': 773.6232041430812, 'scale_pos_weight': 2.7030105092860484, 'subsample': 0.9902068033583249}
#
# Model #8
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #9
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #10
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #11
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #12
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #13
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #14
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #15
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #16
# Best ROC-AUC: 0.772
# Best params: {'colsample_bylevel': 0.8708910829618655, 'colsample_bytree': 0.46934930401203256, 'gamma': 0.20186021826175005, 'learning_rate': 0.02736566935792325, 'max_delta_step': 9, 'max_depth': 13, 'min_child_weight': 3, 'n_estimators': 57, 'reg_alpha': 2.8506373213826874e-06, 'reg_lambda': 8.830563087769766e-06, 'scale_pos_weight': 1.338704175996959, 'subsample': 0.9841735443692645}
#
# Model #17
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #18
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #19
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #20
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #21
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #22
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #23
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #24
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #25
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #26
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #27
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #28
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #29
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #30
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #31
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #32
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #33
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #34
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #35
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #36
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #37
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #38
# Best ROC-AUC: 0.7757
# Best params: {'colsample_bylevel': 0.22607455408484503, 'colsample_bytree': 0.8251922223786592, 'gamma': 4.605613364103205e-09, 'learning_rate': 0.20841370810685014, 'max_delta_step': 2, 'max_depth': 43, 'min_child_weight': 5, 'n_estimators': 52, 'reg_alpha': 3.77443475633027e-07, 'reg_lambda': 11.024432024444248, 'scale_pos_weight': 0.17097808769803452, 'subsample': 0.8071298896725626}
#
# Model #39
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #40
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #41
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #42
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #43
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #44
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Model #45
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #46
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #47
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #48
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #49
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #50
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #51
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #52
# Best ROC-AUC: 0.7763
# Best params: {'colsample_bylevel': 0.37429876941719775, 'colsample_bytree': 0.5279438775496269, 'gamma': 0.49999999999999994, 'learning_rate': 0.4357858610696449, 'max_delta_step': 5, 'max_depth': 46, 'min_child_weight': 0, 'n_estimators': 75, 'reg_alpha': 1.3761261766538657e-06, 'reg_lambda': 1000.0, 'scale_pos_weight': 59.67843001107166, 'subsample': 1.0}
#
# Model #53
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #54
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #55
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #56
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #57
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #58
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #59
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #60
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #61
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #62
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #63
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #64
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #65
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #66
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #67
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #68
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #69
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #70
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #71
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #72
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #73
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #74
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #75
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #76
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #77
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #78
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #79
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #80
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #81
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #82
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #83
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #84
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #85
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #86
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #87
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #88
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #89
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #90
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #91
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #92
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #93
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #94
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #95
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #96
# Best ROC-AUC: 0.7777
# Best params: {'colsample_bylevel': 0.5598449835901195, 'colsample_bytree': 0.3433896802223687, 'gamma': 0.0001007854080535959, 'learning_rate': 0.20660045458889684, 'max_delta_step': 13, 'max_depth': 29, 'min_child_weight': 2, 'n_estimators': 95, 'reg_alpha': 3.538959749695951e-05, 'reg_lambda': 1000.0, 'scale_pos_weight': 499.99999999999994, 'subsample': 0.6128066793183755}
#
# Model #97
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #98
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #99
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #100
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #101
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #102
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #103
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #104
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #105
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #106
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #107
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #108
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #109
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #110
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #111
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #112
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #113
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #114
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #115
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #116
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #117
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #118
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #119
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #120
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #121
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #122
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #123
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #124
# Best ROC-AUC: 0.7784
# Best params: {'colsample_bylevel': 0.15833309506745832, 'colsample_bytree': 0.7889363726814412, 'gamma': 1e-09, 'learning_rate': 0.10720932430594945, 'max_delta_step': 4, 'max_depth': 45, 'min_child_weight': 2, 'n_estimators': 100, 'reg_alpha': 2.680375674545997e-07, 'reg_lambda': 1000.0, 'scale_pos_weight': 9.23976527444799, 'subsample': 1.0}
#
# Model #125
# Best ROC-AUC: 0.7785
# Best params: {'colsample_bylevel': 0.43137229639036795, 'colsample_bytree': 0.4480643933948192, 'gamma': 0.011571057538450112, 'learning_rate': 0.3200409629730479, 'max_delta_step': 0, 'max_depth': 36, 'min_child_weight': 1, 'n_estimators': 92, 'reg_alpha': 1.3963892344511292e-09, 'reg_lambda': 1000.0, 'scale_pos_weight': 1.1507206056795551, 'subsample': 1.0}
#
# Model #126
# Best ROC-AUC: 0.7785
# Best params: {'colsample_bylevel': 0.43137229639036795, 'colsample_bytree': 0.4480643933948192, 'gamma': 0.011571057538450112, 'learning_rate': 0.3200409629730479, 'max_delta_step': 0, 'max_depth': 36, 'min_child_weight': 1, 'n_estimators': 92, 'reg_alpha': 1.3963892344511292e-09, 'reg_lambda': 1000.0, 'scale_pos_weight': 1.1507206056795551, 'subsample': 1.0}
#
# Model #127
# Best ROC-AUC: 0.7785
# Best params: {'colsample_bylevel': 0.43137229639036795, 'colsample_bytree': 0.4480643933948192, 'gamma': 0.011571057538450112, 'learning_rate': 0.3200409629730479, 'max_delta_step': 0, 'max_depth': 36, 'min_child_weight': 1, 'n_estimators': 92, 'reg_alpha': 1.3963892344511292e-09, 'reg_lambda': 1000.0, 'scale_pos_weight': 1.1507206056795551, 'subsample': 1.0}

# %%
#since last rounds gave minimal improvement,
#we'll use last rounds params

xgb_best = xgb.XGBClassifier(colsample_bylevel= 0.43137229639036795, 
                              colsample_bytree= 0.4480643933948192, 
                              gamma= 0.011571057538450112, 
                              learning_rate= 0.3200409629730479, 
                              max_delta_step= 0, 
                              max_depth= 36, 
                              min_child_weight= 1, 
                              n_estimators= 92, 
                              reg_alpha= 1.3963892344511292e-09, 
                              reg_lambda= 1000.0, 
                              scale_pos_weight= 1.1507206056795551, 
                              subsample= 1.0)

# %%
#now we will train and make predictions


clf = xgb_best

clf.fit(Train_data[predictors], Train_data[target])

train_predictions = clf.predict(Train_data[predictors])

#train accuracy, auc, f1 score
print(f"Train Accuracy Score: {metrics.accuracy_score(Train_data[target], train_predictions)}")
print(f"Train AUC Score: {metrics.roc_auc_score(Train_data[target], train_predictions)}")
print(f"Train F1 Score: {metrics.f1_score(Train_data[target], train_predictions)}")
# Out:
# Train Accuracy Score: 0.8283333333333334
# Train AUC Score: 0.6780529404452781
# Train F1 Score: 0.5136921624173749

# %%
# see the results on the test set
test_predictions = clf.predict(test_data[predictors])

#train accuracy, auc, f1 score
print(f"Test Accuracy Score: {metrics.accuracy_score(test_data[target], test_predictions)}")
print(f"Test AUC Score: {metrics.roc_auc_score(test_data[target], test_predictions)}")
print(f"Test F1 Score: {metrics.f1_score(test_data[target], test_predictions)}")
# Out:
# Test Accuracy Score: 0.8275
# Test AUC Score: 0.6694785957635906
# Test F1 Score: 0.4943820224719101

# %%
# %pwd
# Out:
# '/content/2019-competition2-3-musketeers/Kevin'

# %%
#does it beat the best xgboost model from before? No
from sklearn.externals import joblib

xgb4 = joblib.load('Models/xgboost4.dat')

y_pred = xgb4.predict(test_data[predictors])
print(f"Test Accuracy Score: {metrics.accuracy_score(test_data[target], y_pred)}")
print(f"Test AUC Score: {metrics.roc_auc_score(test_data[target], y_pred)}")
print(f"Test F1 Score: {metrics.f1_score(test_data[target], y_pred)}")
# Out:
# Test Accuracy Score: 0.8133333333333334
# Test AUC Score: 0.7071742457907471
# Test F1 Score: 0.5454545454545454

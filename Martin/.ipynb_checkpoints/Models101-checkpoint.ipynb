# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from Modules import *
sns.set()
# %matplotlib inline

# %%
# read the csv & clean up some of the unusual values
df, y = read_data('../default_of_credit_card_clients.xls')
df = proc_cat_df(df)

df.head().T
# Out:
#                                1       2      3      4      5
# LIMIT_BAL                  20000  120000  90000  50000  50000
# AGE                           24      26     34     37     57
# PAY_1                          2      -1      0      0     -1
# PAY_2                          2       2      0      0      0
# PAY_3                         -1       0      0      0     -1
# PAY_4                         -1       0      0      0      0
# PAY_5                         -2       0      0      0      0
# PAY_6                         -2       2      0      0      0
# BILL_AMT1                   3913    2682  29239  46990   8617
# BILL_AMT2                   3102    1725  14027  48233   5670
# BILL_AMT3                    689    2682  13559  49291  35835
# BILL_AMT4                      0    3272  14331  28314  20940
# BILL_AMT5                      0    3455  14948  28959  19146
# BILL_AMT6                      0    3261  15549  29547  19131
# PAY_AMT1                       0       0   1518   2000   2000
# PAY_AMT2                     689    1000   1500   2019  36681
# PAY_AMT3                       0    1000   1000   1200  10000
# PAY_AMT4                       0    1000   1000   1100   9000
# PAY_AMT5                       0       0   1000   1069    689
# PAY_AMT6                       0    2000   5000   1000    679
# Y                              1       1      0      0      0
# SEX_Female                     1       1      1      1      0
# SEX_Male                       0       0      0      0      1
# EDUCATION_Graduate School      0       0      0      0      0
# EDUCATION_Other                0       0      0      0      0
# EDUCATION_University           1       1      1      1      1
# MARRIAGE_Married               1       0      0      1      1
# MARRIAGE_Non-married           0       1      1      0      0

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from Modules import *
sns.set()
# %matplotlib inline
import imblearn
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
#import xgboost as xgb
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
X = df.drop(columns = 'Y')
y = df['Y']

# %%
df.describe()
# Out:
#             LIMIT_BAL           AGE         PAY_1         PAY_2         PAY_3  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     35.485500     -0.016700     -0.133767     -0.166200
# std     129747.661567      9.217904      1.123802      1.197186      1.196868
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%      50000.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     34.000000      0.000000      0.000000      0.000000
# 75%     240000.000000     41.000000      0.000000      0.000000      0.000000
# max    1000000.000000     79.000000      8.000000      8.000000      8.000000
#
#               PAY_4         PAY_5         PAY_6      BILL_AMT1      BILL_AMT2  \
# count  30000.000000  30000.000000  30000.000000   30000.000000   30000.000000
# mean      -0.220667     -0.266200     -0.291100   51223.330900   49179.075167
# std        1.169139      1.133187      1.149988   73635.860576   71173.768783
# min       -2.000000     -2.000000     -2.000000 -165580.000000  -69777.000000
# 25%       -1.000000     -1.000000     -1.000000    3558.750000    2984.750000
# 50%        0.000000      0.000000      0.000000   22381.500000   21200.000000
# 75%        0.000000      0.000000      0.000000   67091.000000   64006.250000
# max        8.000000      8.000000      8.000000  964511.000000  983931.000000
#
#                ...                PAY_AMT5       PAY_AMT6             Y  \
# count          ...            30000.000000   30000.000000  30000.000000
# mean           ...             4799.387633    5215.502567      0.221200
# std            ...            15278.305679   17777.465775      0.415062
# min            ...                0.000000       0.000000      0.000000
# 25%            ...              252.500000     117.750000      0.000000
# 50%            ...             1500.000000    1500.000000      0.000000
# 75%            ...             4031.500000    4000.000000      0.000000
# max            ...           426529.000000  528666.000000      1.000000
#
#          SEX_Female      SEX_Male  EDUCATION_Graduate School  EDUCATION_Other  \
# count  30000.000000  30000.000000               30000.000000     30000.000000
# mean       0.603733      0.396267                   0.352833         0.179500
# std        0.489129      0.489129                   0.477859         0.383777
# min        0.000000      0.000000                   0.000000         0.000000
# 25%        0.000000      0.000000                   0.000000         0.000000
# 50%        1.000000      0.000000                   0.000000         0.000000
# 75%        1.000000      1.000000                   1.000000         0.000000
# max        1.000000      1.000000                   1.000000         1.000000
#
#        EDUCATION_University  MARRIAGE_Married  MARRIAGE_Non-married
# count          30000.000000      30000.000000          30000.000000
# mean               0.467667          0.455300              0.544700
# std                0.498962          0.498006              0.498006
# min                0.000000          0.000000              0.000000
# 25%                0.000000          0.000000              0.000000
# 50%                0.000000          0.000000              1.000000
# 75%                1.000000          1.000000              1.000000
# max                1.000000          1.000000              1.000000
#
# [8 rows x 28 columns]

# %%
X.columns
# Out:
# Index(['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5',
#        'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
#        'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'SEX_Female', 'SEX_Male',
#        'EDUCATION_Graduate School', 'EDUCATION_Other', 'EDUCATION_University',
#        'MARRIAGE_Married', 'MARRIAGE_Non-married'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 2019, test_size = .2)

# %%
from imblearn.over_sampling import SMOTE

#create my oversampled data to train on
oversampler = SMOTE(random_state = 2019)
X_train_oversampled, y_train_oversampled = oversampler.fit_resample(X_train, y_train)

# %%
#Put the oversampled data back into a dataframe
X_train_oversampled = pd.DataFrame(X_train_oversampled, columns = X_train.columns)
y_train_oversampled = pd.Series(y_train_oversampled)

# %%
print("X_train_oversampled", X_train_oversampled.shape)
print("X_test",X_test.shape)
print("y_train_oversampled",y_train_oversampled.shape)
print("y_test",y_test.shape)
# Out:
# X_train_oversampled (37308, 27)
# X_test (6000, 27)
# y_train_oversampled (37308,)
# y_test (6000,)

# %% [markdown]
# # Logistic Regression

# %%
clfLR = LogisticRegression(solver = 'lbfgs',
                           max_iter = 500,
                          random_state = 2019)

i = clfLR.fit(X_train_oversampled,y_train_oversampled)

predLR = clfLR.predict(X_test)

# %%
# Cross Validation
cross_val_score_LR = cross_val_score(clfLR, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LR.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predLR).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predLR).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predLR).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predLR).round(2))
# Out:
# cross_val_score:  0.78
# precision score is  0.29
# recall_score is  0.7155
# f1 score is  0.409
# ROC AUC is  0.61

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(clfLR, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation results: {np.mean(results)}")
# Out:
# 5-fold cross-validation results: 0.0

# %% [markdown]
# # SVC

# %%
clfSVC = SVC(kernel = 'rbf',
             gamma = 'scale',
                random_state = 2019)

p = clfSVC.fit(X_train_oversampled,y_train_oversampled)

predSVC = clfSVC.predict(X_test)

# %%
# Cross Validation
cross_val_score_SVC = cross_val_score(clfSVC, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_SVC.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predSVC).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predSVC).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predSVC).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predSVC).round(2))
# Out:
# cross_val_score:  0.78
# precision score is  0.29
# recall_score is  0.6915
# f1 score is  0.404
# ROC AUC is  0.61

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(p, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation results: {np.mean(results)}")
# Out:
# 5-fold cross-validation results: 0.0

# %% [markdown]
# # Kneighbours

# %%
clfKNN = KNeighborsClassifier(n_neighbors = 3)
clfKNN.fit(X_train_oversampled,y_train_oversampled)

predKNN = clfKNN.predict(X_test)

# %%
# Cross Validation
cross_val_score_KNN = cross_val_score(clfKNN, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_KNN.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predKNN).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predKNN).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predKNN).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predKNN).round(2))
# Out:
# cross_val_score:  0.74
# precision score is  0.27
# recall_score is  0.4705
# f1 score is  0.344
# ROC AUC is  0.56

# %% [markdown]
# # Random Forest Classifier

# %%
clfRF = RandomForestClassifier(criterion = 'gini',
                              n_estimators = 100,
                              verbose = False,
                              random_state = 0)

r = clfRF.fit(X_train_oversampled,y_train_oversampled)

predRF = clfRF.predict(X_test)

# %%
# Cross Validation
cross_val_score_RF = cross_val_score(clfRF, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_RF.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predRF).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predRF).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predRF).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predRF).round(2))
# Out:
# cross_val_score:  0.82
# precision score is  0.59
# recall_score is  0.4488
# f1 score is  0.511
# ROC AUC is  0.68

# %%
#Use 5-fold cross validation to see how well the classfier you built is doing on test data.

kfold = KFold(n_splits=5, random_state=2019)
results = cross_val_score(r, X_test, y_test, cv=kfold, scoring = 'f1')

print(f"5-fold cross-validation results: {np.mean(results)}")
# Out:
# 5-fold cross-validation results: 0.4717615268280517

# %% [markdown]
# # light gbm

# %%
clfLGB = LGBMClassifier(n_estimators = 100,
                           learning_rate = .2,
                           random_state = 0)

clfLGB.fit(X_train_oversampled,y_train_oversampled)

predLGB = clfLGB.predict(X_test)

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfLGB, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predLGB).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predLGB).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predLGB).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predLGB).round(2))
# Out:
# cross_val_score:  0.81
# precision score is  0.64
# recall_score is  0.4047
# f1 score is  0.495
# ROC AUC is  0.67

# %% [markdown]
# # Cat Boost Classifier

# %% [markdown]
# https://catboost.ai/docs/concepts/python-reference_catboostclassifier.html

# %%
clfCB = CatBoostClassifier(iterations = 100,
                           learning_rate = .2,
                           depth = 5,
                           eval_metric = 'AUC',
                           random_seed = 0)

clfCB.fit(X_train_oversampled,y_train_oversampled)

predCB = clfCB.predict(X_test)
# Out:
# 0:	total: 222ms	remaining: 22s
# 1:	total: 297ms	remaining: 14.5s
# 2:	total: 376ms	remaining: 12.1s
# 3:	total: 463ms	remaining: 11.1s
# 4:	total: 536ms	remaining: 10.2s
# 5:	total: 608ms	remaining: 9.53s
# 6:	total: 694ms	remaining: 9.22s
# 7:	total: 779ms	remaining: 8.96s
# 8:	total: 856ms	remaining: 8.66s
# 9:	total: 944ms	remaining: 8.49s
# 10:	total: 1.04s	remaining: 8.46s
# 11:	total: 1.14s	remaining: 8.33s
# 12:	total: 1.22s	remaining: 8.15s
# 13:	total: 1.3s	remaining: 7.99s
# 14:	total: 1.4s	remaining: 7.95s
# 15:	total: 1.49s	remaining: 7.84s
# 16:	total: 1.58s	remaining: 7.71s
# 17:	total: 1.68s	remaining: 7.65s
# 18:	total: 1.76s	remaining: 7.52s
# 19:	total: 1.85s	remaining: 7.4s
# 20:	total: 1.94s	remaining: 7.29s
# 21:	total: 2.03s	remaining: 7.19s
# 22:	total: 2.11s	remaining: 7.06s
# 23:	total: 2.19s	remaining: 6.95s
# 24:	total: 2.28s	remaining: 6.85s
# 25:	total: 2.37s	remaining: 6.73s
# 26:	total: 2.46s	remaining: 6.66s
# 27:	total: 2.55s	remaining: 6.55s
# 28:	total: 2.64s	remaining: 6.46s
# 29:	total: 2.74s	remaining: 6.39s
# 30:	total: 2.83s	remaining: 6.31s
# 31:	total: 2.92s	remaining: 6.21s
# 32:	total: 3.01s	remaining: 6.12s
# 33:	total: 3.11s	remaining: 6.03s
# 34:	total: 3.19s	remaining: 5.93s
# 35:	total: 3.28s	remaining: 5.84s
# 36:	total: 3.37s	remaining: 5.73s
# 37:	total: 3.45s	remaining: 5.63s
# 38:	total: 3.53s	remaining: 5.53s
# 39:	total: 3.63s	remaining: 5.44s
# 40:	total: 3.71s	remaining: 5.34s
# 41:	total: 3.76s	remaining: 5.2s
# 42:	total: 3.85s	remaining: 5.1s
# 43:	total: 3.94s	remaining: 5.01s
# 44:	total: 4.02s	remaining: 4.91s
# 45:	total: 4.1s	remaining: 4.81s
# 46:	total: 4.18s	remaining: 4.72s
# 47:	total: 4.27s	remaining: 4.62s
# 48:	total: 4.35s	remaining: 4.53s
# 49:	total: 4.45s	remaining: 4.45s
# 50:	total: 4.53s	remaining: 4.36s
# 51:	total: 4.62s	remaining: 4.26s
# 52:	total: 4.71s	remaining: 4.18s
# 53:	total: 4.8s	remaining: 4.09s
# 54:	total: 4.89s	remaining: 4s
# 55:	total: 4.97s	remaining: 3.91s
# 56:	total: 5.05s	remaining: 3.81s
# 57:	total: 5.13s	remaining: 3.72s
# 58:	total: 5.22s	remaining: 3.63s
# 59:	total: 5.3s	remaining: 3.54s
# 60:	total: 5.39s	remaining: 3.44s
# 61:	total: 5.48s	remaining: 3.36s
# 62:	total: 5.56s	remaining: 3.27s
# 63:	total: 5.65s	remaining: 3.18s
# 64:	total: 5.76s	remaining: 3.1s
# 65:	total: 5.85s	remaining: 3.01s
# 66:	total: 5.93s	remaining: 2.92s
# 67:	total: 6.03s	remaining: 2.84s
# 68:	total: 6.12s	remaining: 2.75s
# 69:	total: 6.2s	remaining: 2.66s
# 70:	total: 6.29s	remaining: 2.57s
# 71:	total: 6.38s	remaining: 2.48s
# 72:	total: 6.45s	remaining: 2.39s
# 73:	total: 6.54s	remaining: 2.3s
# 74:	total: 6.63s	remaining: 2.21s
# 75:	total: 6.71s	remaining: 2.12s
# 76:	total: 6.81s	remaining: 2.03s
# 77:	total: 6.89s	remaining: 1.94s
# 78:	total: 6.98s	remaining: 1.85s
# 79:	total: 7.06s	remaining: 1.76s
# 80:	total: 7.15s	remaining: 1.68s
# 81:	total: 7.24s	remaining: 1.59s
# 82:	total: 7.33s	remaining: 1.5s
# 83:	total: 7.42s	remaining: 1.41s
# 84:	total: 7.5s	remaining: 1.32s
# 85:	total: 7.6s	remaining: 1.24s
# 86:	total: 7.68s	remaining: 1.15s
# 87:	total: 7.77s	remaining: 1.06s
# 88:	total: 7.87s	remaining: 972ms
# 89:	total: 7.95s	remaining: 883ms
# 90:	total: 8.03s	remaining: 794ms
# 91:	total: 8.12s	remaining: 706ms
# 92:	total: 8.2s	remaining: 617ms
# 93:	total: 8.29s	remaining: 529ms
# 94:	total: 8.39s	remaining: 442ms
# 95:	total: 8.49s	remaining: 354ms
# 96:	total: 8.57s	remaining: 265ms
# 97:	total: 8.65s	remaining: 177ms
# 98:	total: 8.74s	remaining: 88.2ms
# 99:	total: 8.82s	remaining: 0us

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfCB, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, predCB).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, predCB).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, predCB).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, predCB).round(2))
# Out:
# 0:	total: 49.9ms	remaining: 4.94s
# 1:	total: 96.5ms	remaining: 4.73s
# 2:	total: 146ms	remaining: 4.71s
# 3:	total: 192ms	remaining: 4.6s
# 4:	total: 255ms	remaining: 4.85s
# 5:	total: 301ms	remaining: 4.71s
# 6:	total: 349ms	remaining: 4.64s
# 7:	total: 399ms	remaining: 4.59s
# 8:	total: 444ms	remaining: 4.49s
# 9:	total: 489ms	remaining: 4.4s
# 10:	total: 536ms	remaining: 4.33s
# 11:	total: 582ms	remaining: 4.27s
# 12:	total: 630ms	remaining: 4.22s
# 13:	total: 678ms	remaining: 4.16s
# 14:	total: 727ms	remaining: 4.12s
# 15:	total: 773ms	remaining: 4.06s
# 16:	total: 820ms	remaining: 4s
# 17:	total: 880ms	remaining: 4.01s
# 18:	total: 934ms	remaining: 3.98s
# 19:	total: 981ms	remaining: 3.92s
# 20:	total: 1.03s	remaining: 3.88s
# 21:	total: 1.08s	remaining: 3.82s
# 22:	total: 1.12s	remaining: 3.76s
# 23:	total: 1.17s	remaining: 3.7s
# 24:	total: 1.21s	remaining: 3.64s
# 25:	total: 1.26s	remaining: 3.59s
# 26:	total: 1.31s	remaining: 3.54s
# 27:	total: 1.35s	remaining: 3.48s
# 28:	total: 1.41s	remaining: 3.45s
# 29:	total: 1.46s	remaining: 3.4s
# 30:	total: 1.5s	remaining: 3.34s
# 31:	total: 1.53s	remaining: 3.25s
# 32:	total: 1.56s	remaining: 3.17s
# 33:	total: 1.62s	remaining: 3.14s
# 34:	total: 1.66s	remaining: 3.08s
# 35:	total: 1.7s	remaining: 3.03s
# 36:	total: 1.75s	remaining: 2.98s
# 37:	total: 1.8s	remaining: 2.93s
# 38:	total: 1.84s	remaining: 2.88s
# 39:	total: 1.89s	remaining: 2.84s
# 40:	total: 1.94s	remaining: 2.79s
# 41:	total: 2s	remaining: 2.76s
# 42:	total: 2.04s	remaining: 2.71s
# 43:	total: 2.09s	remaining: 2.66s
# 44:	total: 2.15s	remaining: 2.62s
# 45:	total: 2.19s	remaining: 2.58s
# 46:	total: 2.26s	remaining: 2.55s
# 47:	total: 2.33s	remaining: 2.53s
# 48:	total: 2.4s	remaining: 2.5s
# 49:	total: 2.46s	remaining: 2.46s
# 50:	total: 2.53s	remaining: 2.43s
# 51:	total: 2.6s	remaining: 2.4s
# 52:	total: 2.66s	remaining: 2.36s
# 53:	total: 2.72s	remaining: 2.31s
# 54:	total: 2.77s	remaining: 2.27s
# 55:	total: 2.83s	remaining: 2.22s
# 56:	total: 2.89s	remaining: 2.18s
# 57:	total: 2.95s	remaining: 2.14s
# 58:	total: 3.01s	remaining: 2.09s
# 59:	total: 3.08s	remaining: 2.05s
# 60:	total: 3.14s	remaining: 2.01s
# 61:	total: 3.17s	remaining: 1.94s
# 62:	total: 3.22s	remaining: 1.89s
# 63:	total: 3.27s	remaining: 1.84s
# 64:	total: 3.33s	remaining: 1.79s
# 65:	total: 3.38s	remaining: 1.74s
# 66:	total: 3.44s	remaining: 1.7s
# 67:	total: 3.51s	remaining: 1.65s
# 68:	total: 3.56s	remaining: 1.6s
# 69:	total: 3.62s	remaining: 1.55s
# 70:	total: 3.68s	remaining: 1.5s
# 71:	total: 3.74s	remaining: 1.46s
# 72:	total: 3.79s	remaining: 1.4s
# 73:	total: 3.85s	remaining: 1.35s
# 74:	total: 3.92s	remaining: 1.31s
# 75:	total: 3.97s	remaining: 1.25s
# 76:	total: 4.02s	remaining: 1.2s
# 77:	total: 4.07s	remaining: 1.15s
# 78:	total: 4.11s	remaining: 1.09s
# 79:	total: 4.16s	remaining: 1.04s
# 80:	total: 4.22s	remaining: 989ms
# 81:	total: 4.27s	remaining: 937ms
# 82:	total: 4.32s	remaining: 885ms
# 83:	total: 4.37s	remaining: 832ms
# 84:	total: 4.41s	remaining: 779ms
# 85:	total: 4.46s	remaining: 727ms
# 86:	total: 4.51s	remaining: 675ms
# 87:	total: 4.56s	remaining: 622ms
# 88:	total: 4.61s	remaining: 569ms
# 89:	total: 4.65s	remaining: 516ms
# 90:	total: 4.69s	remaining: 464ms
# 91:	total: 4.74s	remaining: 412ms
# 92:	total: 4.78s	remaining: 360ms
# 93:	total: 4.82s	remaining: 308ms
# 94:	total: 4.86s	remaining: 256ms
# 95:	total: 4.91s	remaining: 204ms
# 96:	total: 4.96s	remaining: 153ms
# 97:	total: 5.01s	remaining: 102ms
# 98:	total: 5.05s	remaining: 51ms
# 99:	total: 5.09s	remaining: 0us
# 0:	total: 54.8ms	remaining: 5.42s
# 1:	total: 96.3ms	remaining: 4.72s
# 2:	total: 140ms	remaining: 4.53s
# 3:	total: 179ms	remaining: 4.3s
# 4:	total: 222ms	remaining: 4.21s
# 5:	total: 262ms	remaining: 4.11s
# 6:	total: 309ms	remaining: 4.1s
# 7:	total: 356ms	remaining: 4.1s
# 8:	total: 400ms	remaining: 4.04s
# 9:	total: 443ms	remaining: 3.99s
# 10:	total: 492ms	remaining: 3.98s
# 11:	total: 535ms	remaining: 3.93s
# 12:	total: 582ms	remaining: 3.9s
# 13:	total: 625ms	remaining: 3.84s
# 14:	total: 676ms	remaining: 3.83s
# 15:	total: 723ms	remaining: 3.8s
# 16:	total: 768ms	remaining: 3.75s
# 17:	total: 815ms	remaining: 3.71s
# 18:	total: 862ms	remaining: 3.67s
# 19:	total: 915ms	remaining: 3.66s
# 20:	total: 968ms	remaining: 3.64s
# 21:	total: 1.02s	remaining: 3.61s
# 22:	total: 1.07s	remaining: 3.6s
# 23:	total: 1.12s	remaining: 3.55s
# 24:	total: 1.16s	remaining: 3.49s
# 25:	total: 1.21s	remaining: 3.44s
# 26:	total: 1.25s	remaining: 3.39s
# 27:	total: 1.31s	remaining: 3.37s
# 28:	total: 1.34s	remaining: 3.29s
# 29:	total: 1.37s	remaining: 3.2s
# 30:	total: 1.41s	remaining: 3.13s
# 31:	total: 1.46s	remaining: 3.1s
# 32:	total: 1.5s	remaining: 3.05s
# 33:	total: 1.55s	remaining: 3s
# 34:	total: 1.59s	remaining: 2.96s
# 35:	total: 1.64s	remaining: 2.92s
# 36:	total: 1.69s	remaining: 2.88s
# 37:	total: 1.73s	remaining: 2.83s
# 38:	total: 1.78s	remaining: 2.78s
# 39:	total: 1.82s	remaining: 2.73s
# 40:	total: 1.84s	remaining: 2.65s
# 41:	total: 1.9s	remaining: 2.62s
# 42:	total: 1.95s	remaining: 2.58s
# 43:	total: 1.99s	remaining: 2.54s
# 44:	total: 2.04s	remaining: 2.5s
# 45:	total: 2.09s	remaining: 2.46s
# 46:	total: 2.14s	remaining: 2.41s
# 47:	total: 2.18s	remaining: 2.37s
# 48:	total: 2.23s	remaining: 2.32s
# 49:	total: 2.27s	remaining: 2.27s
# 50:	total: 2.32s	remaining: 2.23s
# 51:	total: 2.37s	remaining: 2.19s
# 52:	total: 2.42s	remaining: 2.15s
# 53:	total: 2.46s	remaining: 2.1s
# 54:	total: 2.51s	remaining: 2.06s
# 55:	total: 2.56s	remaining: 2.01s
# 56:	total: 2.58s	remaining: 1.95s
# 57:	total: 2.63s	remaining: 1.9s
# 58:	total: 2.68s	remaining: 1.86s
# 59:	total: 2.73s	remaining: 1.82s
# 60:	total: 2.77s	remaining: 1.77s
# 61:	total: 2.81s	remaining: 1.72s
# 62:	total: 2.86s	remaining: 1.68s
# 63:	total: 2.9s	remaining: 1.63s
# 64:	total: 2.95s	remaining: 1.59s
# 65:	total: 3s	remaining: 1.54s
# 66:	total: 3.04s	remaining: 1.5s
# 67:	total: 3.09s	remaining: 1.45s
# 68:	total: 3.15s	remaining: 1.41s
# 69:	total: 3.19s	remaining: 1.37s
# 70:	total: 3.24s	remaining: 1.32s
# 71:	total: 3.29s	remaining: 1.28s
# 72:	total: 3.34s	remaining: 1.23s
# 73:	total: 3.38s	remaining: 1.19s
# 74:	total: 3.43s	remaining: 1.14s
# 75:	total: 3.48s	remaining: 1.1s
# 76:	total: 3.52s	remaining: 1.05s
# 77:	total: 3.57s	remaining: 1.01s
# 78:	total: 3.62s	remaining: 961ms
# 79:	total: 3.66s	remaining: 915ms
# 80:	total: 3.71s	remaining: 872ms
# 81:	total: 3.76s	remaining: 826ms
# 82:	total: 3.81s	remaining: 779ms
# 83:	total: 3.85s	remaining: 733ms
# 84:	total: 3.91s	remaining: 690ms
# 85:	total: 3.96s	remaining: 644ms
# 86:	total: 4s	remaining: 598ms
# 87:	total: 4.05s	remaining: 552ms
# 88:	total: 4.09s	remaining: 506ms
# 89:	total: 4.15s	remaining: 461ms
# 90:	total: 4.2s	remaining: 415ms
# 91:	total: 4.24s	remaining: 369ms
# 92:	total: 4.29s	remaining: 323ms
# 93:	total: 4.34s	remaining: 277ms
# 94:	total: 4.39s	remaining: 231ms
# 95:	total: 4.44s	remaining: 185ms
# 96:	total: 4.48s	remaining: 139ms
# 97:	total: 4.53s	remaining: 92.5ms
# 98:	total: 4.58s	remaining: 46.3ms
# 99:	total: 4.63s	remaining: 0us
# 0:	total: 66.6ms	remaining: 6.59s
# 1:	total: 110ms	remaining: 5.39s
# 2:	total: 160ms	remaining: 5.18s
# 3:	total: 202ms	remaining: 4.84s
# 4:	total: 245ms	remaining: 4.66s
# 5:	total: 304ms	remaining: 4.77s
# 6:	total: 348ms	remaining: 4.62s
# 7:	total: 395ms	remaining: 4.54s
# 8:	total: 439ms	remaining: 4.44s
# 9:	total: 482ms	remaining: 4.34s
# 10:	total: 528ms	remaining: 4.27s
# 11:	total: 570ms	remaining: 4.18s
# 12:	total: 614ms	remaining: 4.11s
# 13:	total: 663ms	remaining: 4.07s
# 14:	total: 706ms	remaining: 4s
# 15:	total: 760ms	remaining: 3.99s
# 16:	total: 809ms	remaining: 3.95s
# 17:	total: 857ms	remaining: 3.9s
# 18:	total: 907ms	remaining: 3.87s
# 19:	total: 965ms	remaining: 3.86s
# 20:	total: 1.01s	remaining: 3.81s
# 21:	total: 1.06s	remaining: 3.75s
# 22:	total: 1.11s	remaining: 3.71s
# 23:	total: 1.16s	remaining: 3.66s
# 24:	total: 1.22s	remaining: 3.65s
# 25:	total: 1.27s	remaining: 3.61s
# 26:	total: 1.32s	remaining: 3.56s
# 27:	total: 1.37s	remaining: 3.51s
# 28:	total: 1.42s	remaining: 3.46s
# 29:	total: 1.47s	remaining: 3.42s
# 30:	total: 1.51s	remaining: 3.37s
# 31:	total: 1.56s	remaining: 3.31s
# 32:	total: 1.61s	remaining: 3.26s
# 33:	total: 1.66s	remaining: 3.22s
# 34:	total: 1.71s	remaining: 3.18s
# 35:	total: 1.76s	remaining: 3.13s
# 36:	total: 1.81s	remaining: 3.08s
# 37:	total: 1.86s	remaining: 3.03s
# 38:	total: 1.91s	remaining: 2.99s
# 39:	total: 1.97s	remaining: 2.95s
# 40:	total: 2.01s	remaining: 2.89s
# 41:	total: 2.04s	remaining: 2.82s
# 42:	total: 2.09s	remaining: 2.77s
# 43:	total: 2.14s	remaining: 2.72s
# 44:	total: 2.18s	remaining: 2.67s
# 45:	total: 2.21s	remaining: 2.59s
# 46:	total: 2.25s	remaining: 2.54s
# 47:	total: 2.3s	remaining: 2.49s
# 48:	total: 2.35s	remaining: 2.44s
# 49:	total: 2.39s	remaining: 2.39s
# 50:	total: 2.43s	remaining: 2.34s
# 51:	total: 2.48s	remaining: 2.29s
# 52:	total: 2.53s	remaining: 2.24s
# 53:	total: 2.57s	remaining: 2.19s
# 54:	total: 2.62s	remaining: 2.14s
# 55:	total: 2.66s	remaining: 2.09s
# 56:	total: 2.71s	remaining: 2.04s
# 57:	total: 2.76s	remaining: 2s
# 58:	total: 2.8s	remaining: 1.95s
# 59:	total: 2.83s	remaining: 1.88s
# 60:	total: 2.87s	remaining: 1.83s
# 61:	total: 2.92s	remaining: 1.79s
# 62:	total: 2.97s	remaining: 1.75s
# 63:	total: 3.02s	remaining: 1.7s
# 64:	total: 3.06s	remaining: 1.65s
# 65:	total: 3.12s	remaining: 1.6s
# 66:	total: 3.16s	remaining: 1.56s
# 67:	total: 3.21s	remaining: 1.51s
# 68:	total: 3.25s	remaining: 1.46s
# 69:	total: 3.3s	remaining: 1.41s
# 70:	total: 3.35s	remaining: 1.37s
# 71:	total: 3.4s	remaining: 1.32s
# 72:	total: 3.45s	remaining: 1.27s
# 73:	total: 3.49s	remaining: 1.23s
# 74:	total: 3.54s	remaining: 1.18s
# 75:	total: 3.58s	remaining: 1.13s
# 76:	total: 3.63s	remaining: 1.08s
# 77:	total: 3.68s	remaining: 1.04s
# 78:	total: 3.73s	remaining: 991ms
# 79:	total: 3.77s	remaining: 944ms
# 80:	total: 3.82s	remaining: 897ms
# 81:	total: 3.87s	remaining: 850ms
# 82:	total: 3.92s	remaining: 803ms
# 83:	total: 3.97s	remaining: 756ms
# 84:	total: 4.01s	remaining: 708ms
# 85:	total: 4.06s	remaining: 661ms
# 86:	total: 4.11s	remaining: 614ms
# 87:	total: 4.16s	remaining: 567ms
# 88:	total: 4.2s	remaining: 519ms
# 89:	total: 4.25s	remaining: 473ms
# 90:	total: 4.3s	remaining: 425ms
# 91:	total: 4.35s	remaining: 378ms
# 92:	total: 4.39s	remaining: 331ms
# 93:	total: 4.44s	remaining: 283ms
# 94:	total: 4.48s	remaining: 236ms
# 95:	total: 4.53s	remaining: 189ms
# 96:	total: 4.57s	remaining: 141ms
# 97:	total: 4.63s	remaining: 94.5ms
# 98:	total: 4.68s	remaining: 47.3ms
# 99:	total: 4.73s	remaining: 0us
# 0:	total: 66ms	remaining: 6.53s
# 1:	total: 115ms	remaining: 5.63s
# 2:	total: 163ms	remaining: 5.27s
# 3:	total: 209ms	remaining: 5.01s
# 4:	total: 259ms	remaining: 4.92s
# 5:	total: 310ms	remaining: 4.85s
# 6:	total: 355ms	remaining: 4.71s
# 7:	total: 397ms	remaining: 4.56s
# 8:	total: 451ms	remaining: 4.56s
# 9:	total: 497ms	remaining: 4.47s
# 10:	total: 542ms	remaining: 4.38s
# 11:	total: 588ms	remaining: 4.31s
# 12:	total: 611ms	remaining: 4.08s
# 13:	total: 654ms	remaining: 4.02s
# 14:	total: 700ms	remaining: 3.96s
# 15:	total: 745ms	remaining: 3.91s
# 16:	total: 798ms	remaining: 3.9s
# 17:	total: 844ms	remaining: 3.84s
# 18:	total: 908ms	remaining: 3.87s
# 19:	total: 958ms	remaining: 3.83s
# 20:	total: 1.01s	remaining: 3.81s
# 21:	total: 1.07s	remaining: 3.79s
# 22:	total: 1.12s	remaining: 3.75s
# 23:	total: 1.17s	remaining: 3.69s
# 24:	total: 1.21s	remaining: 3.63s
# 25:	total: 1.25s	remaining: 3.57s
# 26:	total: 1.31s	remaining: 3.55s
# 27:	total: 1.36s	remaining: 3.51s
# 28:	total: 1.41s	remaining: 3.46s
# 29:	total: 1.46s	remaining: 3.41s
# 30:	total: 1.5s	remaining: 3.35s
# 31:	total: 1.55s	remaining: 3.29s
# 32:	total: 1.59s	remaining: 3.23s
# 33:	total: 1.64s	remaining: 3.18s
# 34:	total: 1.7s	remaining: 3.15s
# 35:	total: 1.74s	remaining: 3.09s
# 36:	total: 1.78s	remaining: 3.04s
# 37:	total: 1.83s	remaining: 2.99s
# 38:	total: 1.88s	remaining: 2.93s
# 39:	total: 1.93s	remaining: 2.89s
# 40:	total: 1.97s	remaining: 2.84s
# 41:	total: 2.02s	remaining: 2.79s
# 42:	total: 2.07s	remaining: 2.74s
# 43:	total: 2.12s	remaining: 2.69s
# 44:	total: 2.16s	remaining: 2.64s
# 45:	total: 2.21s	remaining: 2.6s
# 46:	total: 2.26s	remaining: 2.55s
# 47:	total: 2.31s	remaining: 2.51s
# 48:	total: 2.36s	remaining: 2.46s
# 49:	total: 2.41s	remaining: 2.41s
# 50:	total: 2.46s	remaining: 2.36s
# 51:	total: 2.51s	remaining: 2.32s
# 52:	total: 2.56s	remaining: 2.27s
# 53:	total: 2.62s	remaining: 2.23s
# 54:	total: 2.67s	remaining: 2.18s
# 55:	total: 2.71s	remaining: 2.13s
# 56:	total: 2.76s	remaining: 2.08s
# 57:	total: 2.81s	remaining: 2.04s
# 58:	total: 2.86s	remaining: 1.99s
# 59:	total: 2.92s	remaining: 1.94s
# 60:	total: 2.97s	remaining: 1.9s
# 61:	total: 3.01s	remaining: 1.85s
# 62:	total: 3.06s	remaining: 1.8s
# 63:	total: 3.11s	remaining: 1.75s
# 64:	total: 3.17s	remaining: 1.7s
# 65:	total: 3.26s	remaining: 1.68s
# 66:	total: 3.34s	remaining: 1.64s
# 67:	total: 3.4s	remaining: 1.6s
# 68:	total: 3.45s	remaining: 1.55s
# 69:	total: 3.52s	remaining: 1.51s
# 70:	total: 3.59s	remaining: 1.47s
# 71:	total: 3.65s	remaining: 1.42s
# 72:	total: 3.71s	remaining: 1.37s
# 73:	total: 3.77s	remaining: 1.32s
# 74:	total: 3.83s	remaining: 1.28s
# 75:	total: 3.87s	remaining: 1.22s
# 76:	total: 3.92s	remaining: 1.17s
# 77:	total: 3.99s	remaining: 1.12s
# 78:	total: 4.05s	remaining: 1.07s
# 79:	total: 4.1s	remaining: 1.02s
# 80:	total: 4.16s	remaining: 976ms
# 81:	total: 4.22s	remaining: 927ms
# 82:	total: 4.28s	remaining: 876ms
# 83:	total: 4.33s	remaining: 825ms
# 84:	total: 4.4s	remaining: 776ms
# 85:	total: 4.45s	remaining: 725ms
# 86:	total: 4.52s	remaining: 675ms
# 87:	total: 4.57s	remaining: 623ms
# 88:	total: 4.64s	remaining: 574ms
# 89:	total: 4.7s	remaining: 522ms
# 90:	total: 4.77s	remaining: 472ms
# 91:	total: 4.83s	remaining: 420ms
# 92:	total: 4.88s	remaining: 368ms
# 93:	total: 4.94s	remaining: 315ms
# 94:	total: 4.99s	remaining: 263ms
# 95:	total: 5.05s	remaining: 210ms
# 96:	total: 5.09s	remaining: 157ms
# 97:	total: 5.14s	remaining: 105ms
# 98:	total: 5.18s	remaining: 52.4ms
# 99:	total: 5.24s	remaining: 0us
# 0:	total: 61.7ms	remaining: 6.11s
# 1:	total: 111ms	remaining: 5.45s
# 2:	total: 153ms	remaining: 4.96s
# 3:	total: 201ms	remaining: 4.82s
# 4:	total: 246ms	remaining: 4.67s
# 5:	total: 292ms	remaining: 4.57s
# 6:	total: 332ms	remaining: 4.41s
# 7:	total: 379ms	remaining: 4.36s
# 8:	total: 423ms	remaining: 4.27s
# 9:	total: 474ms	remaining: 4.27s
# 10:	total: 519ms	remaining: 4.2s
# 11:	total: 564ms	remaining: 4.14s
# 12:	total: 607ms	remaining: 4.07s
# 13:	total: 652ms	remaining: 4s
# 14:	total: 699ms	remaining: 3.96s
# 15:	total: 748ms	remaining: 3.92s
# 16:	total: 794ms	remaining: 3.88s
# 17:	total: 839ms	remaining: 3.82s
# 18:	total: 887ms	remaining: 3.78s
# 19:	total: 937ms	remaining: 3.75s
# 20:	total: 990ms	remaining: 3.72s
# 21:	total: 1.04s	remaining: 3.67s
# 22:	total: 1.09s	remaining: 3.64s
# 23:	total: 1.14s	remaining: 3.61s
# 24:	total: 1.19s	remaining: 3.58s
# 25:	total: 1.24s	remaining: 3.54s
# 26:	total: 1.29s	remaining: 3.49s
# 27:	total: 1.34s	remaining: 3.46s
# 28:	total: 1.4s	remaining: 3.42s
# 29:	total: 1.44s	remaining: 3.37s
# 30:	total: 1.49s	remaining: 3.32s
# 31:	total: 1.54s	remaining: 3.28s
# 32:	total: 1.59s	remaining: 3.23s
# 33:	total: 1.63s	remaining: 3.17s
# 34:	total: 1.68s	remaining: 3.12s
# 35:	total: 1.73s	remaining: 3.07s
# 36:	total: 1.77s	remaining: 3.02s
# 37:	total: 1.82s	remaining: 2.98s
# 38:	total: 1.87s	remaining: 2.93s
# 39:	total: 1.92s	remaining: 2.87s
# 40:	total: 1.96s	remaining: 2.83s
# 41:	total: 2.01s	remaining: 2.78s
# 42:	total: 2.07s	remaining: 2.74s
# 43:	total: 2.11s	remaining: 2.69s
# 44:	total: 2.17s	remaining: 2.65s
# 45:	total: 2.21s	remaining: 2.6s
# 46:	total: 2.26s	remaining: 2.55s
# 47:	total: 2.31s	remaining: 2.5s
# 48:	total: 2.37s	remaining: 2.47s
# 49:	total: 2.42s	remaining: 2.42s
# 50:	total: 2.48s	remaining: 2.38s
# 51:	total: 2.53s	remaining: 2.34s
# 52:	total: 2.59s	remaining: 2.29s
# 53:	total: 2.63s	remaining: 2.24s
# 54:	total: 2.68s	remaining: 2.19s
# 55:	total: 2.73s	remaining: 2.14s
# 56:	total: 2.78s	remaining: 2.1s
# 57:	total: 2.82s	remaining: 2.04s
# 58:	total: 2.87s	remaining: 2s
# 59:	total: 2.93s	remaining: 1.95s
# 60:	total: 2.97s	remaining: 1.9s
# 61:	total: 3.02s	remaining: 1.85s
# 62:	total: 3.06s	remaining: 1.8s
# 63:	total: 3.11s	remaining: 1.75s
# 64:	total: 3.15s	remaining: 1.7s
# 65:	total: 3.21s	remaining: 1.65s
# 66:	total: 3.26s	remaining: 1.61s
# 67:	total: 3.31s	remaining: 1.56s
# 68:	total: 3.36s	remaining: 1.51s
# 69:	total: 3.38s	remaining: 1.45s
# 70:	total: 3.44s	remaining: 1.4s
# 71:	total: 3.48s	remaining: 1.35s
# 72:	total: 3.52s	remaining: 1.3s
# 73:	total: 3.57s	remaining: 1.25s
# 74:	total: 3.61s	remaining: 1.2s
# 75:	total: 3.66s	remaining: 1.16s
# 76:	total: 3.71s	remaining: 1.11s
# 77:	total: 3.75s	remaining: 1.06s
# 78:	total: 3.79s	remaining: 1.01s
# 79:	total: 3.84s	remaining: 960ms
# 80:	total: 3.89s	remaining: 912ms
# 81:	total: 3.93s	remaining: 863ms
# 82:	total: 3.98s	remaining: 816ms
# 83:	total: 4.03s	remaining: 768ms
# 84:	total: 4.08s	remaining: 719ms
# 85:	total: 4.13s	remaining: 672ms
# 86:	total: 4.17s	remaining: 624ms
# 87:	total: 4.22s	remaining: 575ms
# 88:	total: 4.27s	remaining: 528ms
# 89:	total: 4.32s	remaining: 480ms
# 90:	total: 4.37s	remaining: 432ms
# 91:	total: 4.42s	remaining: 384ms
# 92:	total: 4.46s	remaining: 336ms
# 93:	total: 4.51s	remaining: 288ms
# 94:	total: 4.57s	remaining: 240ms
# 95:	total: 4.61s	remaining: 192ms
# 96:	total: 4.66s	remaining: 144ms
# 97:	total: 4.72s	remaining: 96.3ms
# 98:	total: 4.77s	remaining: 48.2ms
# 99:	total: 4.81s	remaining: 0us
# 0:	total: 48.8ms	remaining: 4.83s
# 1:	total: 92.6ms	remaining: 4.54s
# 2:	total: 135ms	remaining: 4.37s
# 3:	total: 180ms	remaining: 4.33s
# 4:	total: 229ms	remaining: 4.36s
# 5:	total: 280ms	remaining: 4.39s
# 6:	total: 327ms	remaining: 4.34s
# 7:	total: 373ms	remaining: 4.29s
# 8:	total: 419ms	remaining: 4.24s
# 9:	total: 462ms	remaining: 4.16s
# 10:	total: 508ms	remaining: 4.11s
# 11:	total: 566ms	remaining: 4.15s
# 12:	total: 614ms	remaining: 4.11s
# 13:	total: 663ms	remaining: 4.07s
# 14:	total: 710ms	remaining: 4.02s
# 15:	total: 759ms	remaining: 3.98s
# 16:	total: 804ms	remaining: 3.92s
# 17:	total: 850ms	remaining: 3.87s
# 18:	total: 903ms	remaining: 3.85s
# 19:	total: 964ms	remaining: 3.86s
# 20:	total: 1.01s	remaining: 3.8s
# 21:	total: 1.06s	remaining: 3.77s
# 22:	total: 1.11s	remaining: 3.72s
# 23:	total: 1.16s	remaining: 3.67s
# 24:	total: 1.21s	remaining: 3.62s
# 25:	total: 1.25s	remaining: 3.56s
# 26:	total: 1.3s	remaining: 3.52s
# 27:	total: 1.35s	remaining: 3.47s
# 28:	total: 1.4s	remaining: 3.42s
# 29:	total: 1.44s	remaining: 3.36s
# 30:	total: 1.48s	remaining: 3.3s
# 31:	total: 1.53s	remaining: 3.25s
# 32:	total: 1.58s	remaining: 3.21s
# 33:	total: 1.63s	remaining: 3.16s
# 34:	total: 1.68s	remaining: 3.12s
# 35:	total: 1.72s	remaining: 3.06s
# 36:	total: 1.77s	remaining: 3.01s
# 37:	total: 1.81s	remaining: 2.96s
# 38:	total: 1.86s	remaining: 2.91s
# 39:	total: 1.91s	remaining: 2.87s
# 40:	total: 1.96s	remaining: 2.82s
# 41:	total: 2.01s	remaining: 2.78s
# 42:	total: 2.07s	remaining: 2.74s
# 43:	total: 2.13s	remaining: 2.71s
# 44:	total: 2.18s	remaining: 2.67s
# 45:	total: 2.24s	remaining: 2.63s
# 46:	total: 2.29s	remaining: 2.58s
# 47:	total: 2.33s	remaining: 2.53s
# 48:	total: 2.38s	remaining: 2.48s
# 49:	total: 2.42s	remaining: 2.42s
# 50:	total: 2.47s	remaining: 2.38s
# 51:	total: 2.52s	remaining: 2.33s
# 52:	total: 2.57s	remaining: 2.28s
# 53:	total: 2.62s	remaining: 2.23s
# 54:	total: 2.67s	remaining: 2.18s
# 55:	total: 2.72s	remaining: 2.14s
# 56:	total: 2.77s	remaining: 2.09s
# 57:	total: 2.81s	remaining: 2.03s
# 58:	total: 2.86s	remaining: 1.99s
# 59:	total: 2.9s	remaining: 1.94s
# 60:	total: 2.95s	remaining: 1.89s
# 61:	total: 3s	remaining: 1.84s
# 62:	total: 3.05s	remaining: 1.79s
# 63:	total: 3.1s	remaining: 1.74s
# 64:	total: 3.14s	remaining: 1.69s
# 65:	total: 3.2s	remaining: 1.65s
# 66:	total: 3.24s	remaining: 1.6s
# 67:	total: 3.29s	remaining: 1.55s
# 68:	total: 3.33s	remaining: 1.5s
# 69:	total: 3.38s	remaining: 1.45s
# 70:	total: 3.43s	remaining: 1.4s
# 71:	total: 3.48s	remaining: 1.35s
# 72:	total: 3.52s	remaining: 1.3s
# 73:	total: 3.57s	remaining: 1.25s
# 74:	total: 3.61s	remaining: 1.2s
# 75:	total: 3.66s	remaining: 1.16s
# 76:	total: 3.71s	remaining: 1.11s
# 77:	total: 3.75s	remaining: 1.06s
# 78:	total: 3.8s	remaining: 1.01s
# 79:	total: 3.85s	remaining: 962ms
# 80:	total: 3.89s	remaining: 914ms
# 81:	total: 3.94s	remaining: 864ms
# 82:	total: 3.99s	remaining: 817ms
# 83:	total: 4.04s	remaining: 769ms
# 84:	total: 4.08s	remaining: 721ms
# 85:	total: 4.13s	remaining: 673ms
# 86:	total: 4.18s	remaining: 625ms
# 87:	total: 4.22s	remaining: 576ms
# 88:	total: 4.28s	remaining: 528ms
# 89:	total: 4.32s	remaining: 480ms
# 90:	total: 4.37s	remaining: 432ms
# 91:	total: 4.42s	remaining: 384ms
# 92:	total: 4.47s	remaining: 336ms
# 93:	total: 4.51s	remaining: 288ms
# 94:	total: 4.56s	remaining: 240ms
# 95:	total: 4.61s	remaining: 192ms
# 96:	total: 4.66s	remaining: 144ms
# 97:	total: 4.71s	remaining: 96.2ms
# 98:	total: 4.76s	remaining: 48.1ms
# 99:	total: 4.81s	remaining: 0us
# 0:	total: 53.6ms	remaining: 5.31s
# 1:	total: 97ms	remaining: 4.75s
# 2:	total: 141ms	remaining: 4.56s
# 3:	total: 184ms	remaining: 4.41s
# 4:	total: 229ms	remaining: 4.34s
# 5:	total: 281ms	remaining: 4.41s
# 6:	total: 329ms	remaining: 4.37s
# 7:	total: 371ms	remaining: 4.27s
# 8:	total: 422ms	remaining: 4.26s
# 9:	total: 478ms	remaining: 4.3s
# 10:	total: 529ms	remaining: 4.28s
# 11:	total: 575ms	remaining: 4.22s
# 12:	total: 623ms	remaining: 4.17s
# 13:	total: 682ms	remaining: 4.19s
# 14:	total: 754ms	remaining: 4.27s
# 15:	total: 804ms	remaining: 4.22s
# 16:	total: 864ms	remaining: 4.22s
# 17:	total: 942ms	remaining: 4.29s
# 18:	total: 1.07s	remaining: 4.57s
# 19:	total: 1.18s	remaining: 4.73s
# 20:	total: 1.28s	remaining: 4.82s
# 21:	total: 1.35s	remaining: 4.8s
# 22:	total: 1.42s	remaining: 4.74s
# 23:	total: 1.47s	remaining: 4.66s
# 24:	total: 1.52s	remaining: 4.57s
# 25:	total: 1.58s	remaining: 4.49s
# 26:	total: 1.64s	remaining: 4.42s
# 27:	total: 1.7s	remaining: 4.38s
# 28:	total: 1.76s	remaining: 4.32s
# 29:	total: 1.81s	remaining: 4.23s
# 30:	total: 1.86s	remaining: 4.15s
# 31:	total: 1.93s	remaining: 4.09s
# 32:	total: 1.98s	remaining: 4.01s
# 33:	total: 2.02s	remaining: 3.93s
# 34:	total: 2.09s	remaining: 3.88s
# 35:	total: 2.14s	remaining: 3.8s
# 36:	total: 2.19s	remaining: 3.72s
# 37:	total: 2.23s	remaining: 3.65s
# 38:	total: 2.29s	remaining: 3.58s
# 39:	total: 2.34s	remaining: 3.51s
# 40:	total: 2.39s	remaining: 3.44s
# 41:	total: 2.43s	remaining: 3.36s
# 42:	total: 2.48s	remaining: 3.29s
# 43:	total: 2.53s	remaining: 3.22s
# 44:	total: 2.58s	remaining: 3.15s
# 45:	total: 2.63s	remaining: 3.08s
# 46:	total: 2.67s	remaining: 3.01s
# 47:	total: 2.72s	remaining: 2.94s
# 48:	total: 2.78s	remaining: 2.89s
# 49:	total: 2.83s	remaining: 2.83s
# 50:	total: 2.87s	remaining: 2.76s
# 51:	total: 2.92s	remaining: 2.69s
# 52:	total: 2.97s	remaining: 2.63s
# 53:	total: 3.02s	remaining: 2.57s
# 54:	total: 3.06s	remaining: 2.51s
# 55:	total: 3.1s	remaining: 2.44s
# 56:	total: 3.14s	remaining: 2.37s
# 57:	total: 3.19s	remaining: 2.31s
# 58:	total: 3.24s	remaining: 2.25s
# 59:	total: 3.27s	remaining: 2.18s
# 60:	total: 3.32s	remaining: 2.12s
# 61:	total: 3.36s	remaining: 2.06s
# 62:	total: 3.41s	remaining: 2s
# 63:	total: 3.45s	remaining: 1.94s
# 64:	total: 3.49s	remaining: 1.88s
# 65:	total: 3.54s	remaining: 1.82s
# 66:	total: 3.58s	remaining: 1.76s
# 67:	total: 3.62s	remaining: 1.71s
# 68:	total: 3.67s	remaining: 1.65s
# 69:	total: 3.77s	remaining: 1.61s
# 70:	total: 3.83s	remaining: 1.56s
# 71:	total: 3.89s	remaining: 1.51s
# 72:	total: 3.94s	remaining: 1.46s
# 73:	total: 4.02s	remaining: 1.41s
# 74:	total: 4.08s	remaining: 1.36s
# 75:	total: 4.15s	remaining: 1.31s
# 76:	total: 4.2s	remaining: 1.25s
# 77:	total: 4.26s	remaining: 1.2s
# 78:	total: 4.31s	remaining: 1.15s
# 79:	total: 4.37s	remaining: 1.09s
# 80:	total: 4.43s	remaining: 1.04s
# 81:	total: 4.5s	remaining: 987ms
# 82:	total: 4.57s	remaining: 936ms
# 83:	total: 4.64s	remaining: 883ms
# 84:	total: 4.68s	remaining: 827ms
# 85:	total: 4.74s	remaining: 772ms
# 86:	total: 4.8s	remaining: 717ms
# 87:	total: 4.86s	remaining: 663ms
# 88:	total: 4.92s	remaining: 608ms
# 89:	total: 4.98s	remaining: 554ms
# 90:	total: 5.04s	remaining: 499ms
# 91:	total: 5.1s	remaining: 443ms
# 92:	total: 5.16s	remaining: 388ms
# 93:	total: 5.22s	remaining: 333ms
# 94:	total: 5.29s	remaining: 278ms
# 95:	total: 5.36s	remaining: 223ms
# 96:	total: 5.41s	remaining: 167ms
# 97:	total: 5.47s	remaining: 112ms
# 98:	total: 5.53s	remaining: 55.8ms
# 99:	total: 5.58s	remaining: 0us
# 0:	total: 55ms	remaining: 5.45s
# 1:	total: 102ms	remaining: 4.97s
# 2:	total: 147ms	remaining: 4.75s
# 3:	total: 193ms	remaining: 4.64s
# 4:	total: 241ms	remaining: 4.59s
# 5:	total: 295ms	remaining: 4.63s
# 6:	total: 336ms	remaining: 4.46s
# 7:	total: 379ms	remaining: 4.36s
# 8:	total: 421ms	remaining: 4.26s
# 9:	total: 462ms	remaining: 4.16s
# 10:	total: 503ms	remaining: 4.07s
# 11:	total: 547ms	remaining: 4.01s
# 12:	total: 591ms	remaining: 3.95s
# 13:	total: 646ms	remaining: 3.97s
# 14:	total: 692ms	remaining: 3.92s
# 15:	total: 740ms	remaining: 3.88s
# 16:	total: 783ms	remaining: 3.82s
# 17:	total: 823ms	remaining: 3.75s
# 18:	total: 879ms	remaining: 3.75s
# 19:	total: 929ms	remaining: 3.71s
# 20:	total: 986ms	remaining: 3.71s
# 21:	total: 1.03s	remaining: 3.66s
# 22:	total: 1.07s	remaining: 3.6s
# 23:	total: 1.13s	remaining: 3.56s
# 24:	total: 1.17s	remaining: 3.51s
# 25:	total: 1.22s	remaining: 3.48s
# 26:	total: 1.27s	remaining: 3.42s
# 27:	total: 1.32s	remaining: 3.38s
# 28:	total: 1.37s	remaining: 3.35s
# 29:	total: 1.42s	remaining: 3.32s
# 30:	total: 1.47s	remaining: 3.28s
# 31:	total: 1.53s	remaining: 3.25s
# 32:	total: 1.58s	remaining: 3.21s
# 33:	total: 1.62s	remaining: 3.15s
# 34:	total: 1.67s	remaining: 3.1s
# 35:	total: 1.72s	remaining: 3.06s
# 36:	total: 1.77s	remaining: 3.02s
# 37:	total: 1.82s	remaining: 2.98s
# 38:	total: 1.88s	remaining: 2.95s
# 39:	total: 1.93s	remaining: 2.9s
# 40:	total: 1.98s	remaining: 2.85s
# 41:	total: 2.03s	remaining: 2.8s
# 42:	total: 2.07s	remaining: 2.75s
# 43:	total: 2.13s	remaining: 2.7s
# 44:	total: 2.18s	remaining: 2.66s
# 45:	total: 2.22s	remaining: 2.61s
# 46:	total: 2.27s	remaining: 2.55s
# 47:	total: 2.32s	remaining: 2.51s
# 48:	total: 2.37s	remaining: 2.46s
# 49:	total: 2.41s	remaining: 2.41s
# 50:	total: 2.46s	remaining: 2.37s
# 51:	total: 2.51s	remaining: 2.32s
# 52:	total: 2.56s	remaining: 2.27s
# 53:	total: 2.61s	remaining: 2.22s
# 54:	total: 2.67s	remaining: 2.18s
# 55:	total: 2.71s	remaining: 2.13s
# 56:	total: 2.76s	remaining: 2.08s
# 57:	total: 2.81s	remaining: 2.03s
# 58:	total: 2.86s	remaining: 1.99s
# 59:	total: 2.91s	remaining: 1.94s
# 60:	total: 2.98s	remaining: 1.91s
# 61:	total: 3.06s	remaining: 1.87s
# 62:	total: 3.13s	remaining: 1.84s
# 63:	total: 3.2s	remaining: 1.8s
# 64:	total: 3.26s	remaining: 1.75s
# 65:	total: 3.32s	remaining: 1.71s
# 66:	total: 3.37s	remaining: 1.66s
# 67:	total: 3.44s	remaining: 1.62s
# 68:	total: 3.49s	remaining: 1.57s
# 69:	total: 3.55s	remaining: 1.52s
# 70:	total: 3.61s	remaining: 1.47s
# 71:	total: 3.67s	remaining: 1.43s
# 72:	total: 3.73s	remaining: 1.38s
# 73:	total: 3.78s	remaining: 1.33s
# 74:	total: 3.83s	remaining: 1.28s
# 75:	total: 3.88s	remaining: 1.23s
# 76:	total: 3.93s	remaining: 1.18s
# 77:	total: 3.99s	remaining: 1.12s
# 78:	total: 4.03s	remaining: 1.07s
# 79:	total: 4.08s	remaining: 1.02s
# 80:	total: 4.13s	remaining: 970ms
# 81:	total: 4.19s	remaining: 920ms
# 82:	total: 4.24s	remaining: 868ms
# 83:	total: 4.29s	remaining: 818ms
# 84:	total: 4.35s	remaining: 768ms
# 85:	total: 4.4s	remaining: 717ms
# 86:	total: 4.45s	remaining: 666ms
# 87:	total: 4.5s	remaining: 614ms
# 88:	total: 4.57s	remaining: 564ms
# 89:	total: 4.61s	remaining: 512ms
# 90:	total: 4.66s	remaining: 461ms
# 91:	total: 4.71s	remaining: 410ms
# 92:	total: 4.76s	remaining: 359ms
# 93:	total: 4.81s	remaining: 307ms
# 94:	total: 4.86s	remaining: 256ms
# 95:	total: 4.9s	remaining: 204ms
# 96:	total: 4.95s	remaining: 153ms
# 97:	total: 4.99s	remaining: 102ms
# 98:	total: 5.04s	remaining: 50.9ms
# 99:	total: 5.08s	remaining: 0us
# 0:	total: 43.2ms	remaining: 4.27s
# 1:	total: 91.9ms	remaining: 4.5s
# 2:	total: 145ms	remaining: 4.7s
# 3:	total: 186ms	remaining: 4.47s
# 4:	total: 227ms	remaining: 4.32s
# 5:	total: 279ms	remaining: 4.37s
# 6:	total: 329ms	remaining: 4.37s
# 7:	total: 375ms	remaining: 4.31s
# 8:	total: 417ms	remaining: 4.21s
# 9:	total: 461ms	remaining: 4.15s
# 10:	total: 508ms	remaining: 4.11s
# 11:	total: 561ms	remaining: 4.11s
# 12:	total: 607ms	remaining: 4.06s
# 13:	total: 651ms	remaining: 4s
# 14:	total: 699ms	remaining: 3.96s
# 15:	total: 752ms	remaining: 3.95s
# 16:	total: 798ms	remaining: 3.9s
# 17:	total: 846ms	remaining: 3.85s
# 18:	total: 903ms	remaining: 3.85s
# 19:	total: 966ms	remaining: 3.86s
# 20:	total: 1.02s	remaining: 3.83s
# 21:	total: 1.07s	remaining: 3.79s
# 22:	total: 1.11s	remaining: 3.73s
# 23:	total: 1.16s	remaining: 3.67s
# 24:	total: 1.21s	remaining: 3.62s
# 25:	total: 1.25s	remaining: 3.57s
# 26:	total: 1.3s	remaining: 3.52s
# 27:	total: 1.36s	remaining: 3.5s
# 28:	total: 1.39s	remaining: 3.39s
# 29:	total: 1.44s	remaining: 3.35s
# 30:	total: 1.49s	remaining: 3.32s
# 31:	total: 1.54s	remaining: 3.28s
# 32:	total: 1.59s	remaining: 3.23s
# 33:	total: 1.63s	remaining: 3.17s
# 34:	total: 1.68s	remaining: 3.12s
# 35:	total: 1.74s	remaining: 3.09s
# 36:	total: 1.78s	remaining: 3.04s
# 37:	total: 1.83s	remaining: 2.98s
# 38:	total: 1.87s	remaining: 2.93s
# 39:	total: 1.93s	remaining: 2.89s
# 40:	total: 1.98s	remaining: 2.85s
# 41:	total: 2.03s	remaining: 2.8s
# 42:	total: 2.07s	remaining: 2.75s
# 43:	total: 2.13s	remaining: 2.71s
# 44:	total: 2.18s	remaining: 2.66s
# 45:	total: 2.23s	remaining: 2.62s
# 46:	total: 2.27s	remaining: 2.56s
# 47:	total: 2.33s	remaining: 2.52s
# 48:	total: 2.38s	remaining: 2.48s
# 49:	total: 2.43s	remaining: 2.43s
# 50:	total: 2.47s	remaining: 2.37s
# 51:	total: 2.52s	remaining: 2.33s
# 52:	total: 2.55s	remaining: 2.26s
# 53:	total: 2.6s	remaining: 2.21s
# 54:	total: 2.65s	remaining: 2.17s
# 55:	total: 2.7s	remaining: 2.12s
# 56:	total: 2.75s	remaining: 2.08s
# 57:	total: 2.8s	remaining: 2.03s
# 58:	total: 2.85s	remaining: 1.98s
# 59:	total: 2.89s	remaining: 1.93s
# 60:	total: 2.95s	remaining: 1.88s
# 61:	total: 2.99s	remaining: 1.83s
# 62:	total: 3.04s	remaining: 1.79s
# 63:	total: 3.1s	remaining: 1.74s
# 64:	total: 3.14s	remaining: 1.69s
# 65:	total: 3.18s	remaining: 1.64s
# 66:	total: 3.24s	remaining: 1.6s
# 67:	total: 3.29s	remaining: 1.55s
# 68:	total: 3.33s	remaining: 1.5s
# 69:	total: 3.38s	remaining: 1.45s
# 70:	total: 3.43s	remaining: 1.4s
# 71:	total: 3.48s	remaining: 1.35s
# 72:	total: 3.52s	remaining: 1.3s
# 73:	total: 3.59s	remaining: 1.26s
# 74:	total: 3.63s	remaining: 1.21s
# 75:	total: 3.68s	remaining: 1.16s
# 76:	total: 3.73s	remaining: 1.11s
# 77:	total: 3.78s	remaining: 1.06s
# 78:	total: 3.83s	remaining: 1.02s
# 79:	total: 3.88s	remaining: 970ms
# 80:	total: 3.93s	remaining: 922ms
# 81:	total: 3.98s	remaining: 873ms
# 82:	total: 4.03s	remaining: 826ms
# 83:	total: 4.07s	remaining: 775ms
# 84:	total: 4.12s	remaining: 727ms
# 85:	total: 4.16s	remaining: 678ms
# 86:	total: 4.21s	remaining: 629ms
# 87:	total: 4.26s	remaining: 581ms
# 88:	total: 4.32s	remaining: 534ms
# 89:	total: 4.36s	remaining: 485ms
# 90:	total: 4.41s	remaining: 436ms
# 91:	total: 4.46s	remaining: 388ms
# 92:	total: 4.51s	remaining: 339ms
# 93:	total: 4.55s	remaining: 291ms
# 94:	total: 4.6s	remaining: 242ms
# 95:	total: 4.66s	remaining: 194ms
# 96:	total: 4.71s	remaining: 146ms
# 97:	total: 4.75s	remaining: 97ms
# 98:	total: 4.8s	remaining: 48.5ms
# 99:	total: 4.85s	remaining: 0us
# 0:	total: 68.8ms	remaining: 6.81s
# 1:	total: 131ms	remaining: 6.42s
# 2:	total: 187ms	remaining: 6.05s
# 3:	total: 245ms	remaining: 5.87s
# 4:	total: 311ms	remaining: 5.91s
# 5:	total: 375ms	remaining: 5.87s
# 6:	total: 434ms	remaining: 5.77s
# 7:	total: 489ms	remaining: 5.62s
# 8:	total: 546ms	remaining: 5.52s
# 9:	total: 601ms	remaining: 5.41s
# 10:	total: 657ms	remaining: 5.31s
# 11:	total: 718ms	remaining: 5.26s
# 12:	total: 769ms	remaining: 5.15s
# 13:	total: 825ms	remaining: 5.07s
# 14:	total: 879ms	remaining: 4.98s
# 15:	total: 944ms	remaining: 4.96s
# 16:	total: 1.01s	remaining: 4.94s
# 17:	total: 1.06s	remaining: 4.84s
# 18:	total: 1.11s	remaining: 4.74s
# 19:	total: 1.17s	remaining: 4.67s
# 20:	total: 1.22s	remaining: 4.58s
# 21:	total: 1.28s	remaining: 4.53s
# 22:	total: 1.33s	remaining: 4.44s
# 23:	total: 1.38s	remaining: 4.37s
# 24:	total: 1.43s	remaining: 4.29s
# 25:	total: 1.49s	remaining: 4.23s
# 26:	total: 1.53s	remaining: 4.15s
# 27:	total: 1.59s	remaining: 4.08s
# 28:	total: 1.63s	remaining: 4s
# 29:	total: 1.69s	remaining: 3.95s
# 30:	total: 1.74s	remaining: 3.86s
# 31:	total: 1.78s	remaining: 3.79s
# 32:	total: 1.85s	remaining: 3.75s
# 33:	total: 1.89s	remaining: 3.68s
# 34:	total: 1.95s	remaining: 3.62s
# 35:	total: 2s	remaining: 3.56s
# 36:	total: 2.05s	remaining: 3.49s
# 37:	total: 2.1s	remaining: 3.43s
# 38:	total: 2.15s	remaining: 3.37s
# 39:	total: 2.2s	remaining: 3.3s
# 40:	total: 2.25s	remaining: 3.24s
# 41:	total: 2.3s	remaining: 3.18s
# 42:	total: 2.34s	remaining: 3.11s
# 43:	total: 2.38s	remaining: 3.03s
# 44:	total: 2.43s	remaining: 2.98s
# 45:	total: 2.51s	remaining: 2.95s
# 46:	total: 2.57s	remaining: 2.9s
# 47:	total: 2.62s	remaining: 2.83s
# 48:	total: 2.68s	remaining: 2.79s
# 49:	total: 2.75s	remaining: 2.75s
# 50:	total: 2.81s	remaining: 2.7s
# 51:	total: 2.87s	remaining: 2.65s
# 52:	total: 2.92s	remaining: 2.59s
# 53:	total: 2.97s	remaining: 2.53s
# 54:	total: 3.04s	remaining: 2.49s
# 55:	total: 3.12s	remaining: 2.45s
# 56:	total: 3.19s	remaining: 2.4s
# 57:	total: 3.24s	remaining: 2.35s
# 58:	total: 3.31s	remaining: 2.3s
# 59:	total: 3.37s	remaining: 2.25s
# 60:	total: 3.44s	remaining: 2.2s
# 61:	total: 3.49s	remaining: 2.14s
# 62:	total: 3.54s	remaining: 2.08s
# 63:	total: 3.62s	remaining: 2.04s
# 64:	total: 3.71s	remaining: 2s
# 65:	total: 3.79s	remaining: 1.96s
# 66:	total: 3.87s	remaining: 1.91s
# 67:	total: 3.93s	remaining: 1.85s
# 68:	total: 4s	remaining: 1.79s
# 69:	total: 4.07s	remaining: 1.75s
# 70:	total: 4.13s	remaining: 1.69s
# 71:	total: 4.2s	remaining: 1.63s
# 72:	total: 4.26s	remaining: 1.58s
# 73:	total: 4.33s	remaining: 1.52s
# 74:	total: 4.39s	remaining: 1.47s
# 75:	total: 4.47s	remaining: 1.41s
# 76:	total: 4.53s	remaining: 1.35s
# 77:	total: 4.6s	remaining: 1.3s
# 78:	total: 4.66s	remaining: 1.24s
# 79:	total: 4.71s	remaining: 1.18s
# 80:	total: 4.77s	remaining: 1.12s
# 81:	total: 4.85s	remaining: 1.06s
# 82:	total: 4.9s	remaining: 1s
# 83:	total: 4.97s	remaining: 947ms
# 84:	total: 5.04s	remaining: 890ms
# 85:	total: 5.11s	remaining: 832ms
# 86:	total: 5.17s	remaining: 773ms
# 87:	total: 5.23s	remaining: 714ms
# 88:	total: 5.31s	remaining: 656ms
# 89:	total: 5.38s	remaining: 597ms
# 90:	total: 5.43s	remaining: 537ms
# 91:	total: 5.49s	remaining: 478ms
# 92:	total: 5.56s	remaining: 418ms
# 93:	total: 5.61s	remaining: 358ms
# 94:	total: 5.67s	remaining: 299ms
# 95:	total: 5.72s	remaining: 238ms
# 96:	total: 5.78s	remaining: 179ms
# 97:	total: 5.83s	remaining: 119ms
# 98:	total: 5.9s	remaining: 59.6ms
# 99:	total: 5.95s	remaining: 0us
# cross_val_score:  0.83
# precision score is  0.66
# recall_score is  0.4202
# f1 score is  0.514
# ROC AUC is  0.68

# %% [markdown]
# # Decision Tree

# %%
# Create Decision Tree classifer object
clfTR = DecisionTreeClassifier()

# Train Decision Tree Classifer
clfTR = clfTR.fit(X_train_oversampled,y_train_oversampled)

#Predict the response for test dataset
y_pred = clfTR.predict(X_test)

# %%
# Cross Validation
cross_val_score_LGB = cross_val_score(clfTR, X_test, y_test, cv = 10)
print('cross_val_score: ',cross_val_score_LGB.mean().round(2))

# Precision Score
print('precision score is ',precision_score(y_test, y_pred).round(2))

# Recall Score
print('recall_score is ',recall_score(y_test, y_pred).round(4))
# F1 Score
print('f1 score is ',f1_score(y_test, y_pred).round(3))

# ROC_AUC
print('ROC AUC is ',roc_auc_score(y_test, y_pred).round(2))
# Out:
# cross_val_score:  0.74
# precision score is  0.38
# recall_score is  0.4279
# f1 score is  0.4
# ROC AUC is  0.62

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      4710
#            1       0.38      0.43      0.40      1290
#
#    micro avg       0.72      0.72      0.72      6000
#    macro avg       0.61      0.62      0.61      6000
# weighted avg       0.74      0.72      0.73      6000

# %%
feature_cols = ['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5',
       'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
       'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
       'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'SEX_Female', 'SEX_Male',
       'EDUCATION_Graduate School', 'EDUCATION_Other', 'EDUCATION_University',
       'MARRIAGE_Married',"1"]

# %%
feature_cols
# Out:
# ['LIMIT_BAL',
#  'AGE',
#  'PAY_1',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'SEX_Female',
#  'SEX_Male',
#  'EDUCATION_Graduate School',
#  'EDUCATION_Other',
#  'EDUCATION_University',
#  'MARRIAGE_Married',
#  '1']

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clfTR, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#graph.write_png('diabetes.png')
#Image(graph.create_png())

# %%
# Confusion Matrix
cmLR = confusion_matrix(y_test, predLR)
cmSVC = confusion_matrix(y_test, predSVC)
cmKNN = confusion_matrix(y_test, predKNN)
cmRF = confusion_matrix(y_test, predRF)
cmTR = confusion_matrix(y_test, y_pred)
cmLGB = confusion_matrix(y_test, predLGB)
cmCB = confusion_matrix(y_test, predCB)

# Confusion Matrix List
cmList = [cmLR, cmSVC,cmKNN, cmRF,cmTR,  cmLGB, cmCB]
cmTitle = ['Logistic Regression','Support Vector Machines','K Nearest Neighbors','Random Forest',"Classification Tree", 'LightGB','CatGBM',None]
i = 0
plt.figure()
fig, ax = plt.subplots(2,4, num = 6, figsize = (30,10))
for cm in cmList:
    i += 1
    plt.subplot(2,4,i)
    plt.title(cmTitle[i-1])
    sns.heatmap(cm, annot = True, cmap = 'YlGnBu')
plt.show();
